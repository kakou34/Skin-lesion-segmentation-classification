# %% [markdown]
# #Skin Lesion Classification with Deep Learning

# %% [markdown]
# In this notebook we will train Image Classification models on the original ISIC2017 dataset
#
# The dataset contains:
#
#
# *   Training set: 2000 images
# *   Validation set: 150 images
# *   Test set: 600 images

# %% [markdown]
# • Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
#  • Tensorboard

# %%
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# * Check GPU type

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Jun 15 17:18:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # **Libraries**

# %% [markdown]
# In this section we import the packages and libraries for future use

# %%
# !pip install opencv-python-headless==4.5.2.52

# !pip install git+https://github.com/albumentations-team/albumentations

# %%
# General
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageOps 
from skimage import io
from typing import Optional, Sequence
import copy
import time
import logging
import sys

# Sci-kit learn
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.utils import class_weight

#Pytorch 
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch import Tensor
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
import albumentations as A

# Some progress bar libraries
from tqdm import tqdm

# %% [markdown]
# # **Helper functions**
#
# In this section we define different utils/helper functions that will be usefull for the rest of the notebook

# %% [markdown]
# ##  *Visualization*

# %%
def imshow(inp, title=None):
    """Imshow for Tensor.
       A Function that uses Matplotlib's PyPlot to show an image stored in a pytorch tensor 
       inputs: inp => image stored in tensor 
               title => title to be displayed with the image 
       returns: None

    """
    inp = inp.numpy().transpose((1, 2, 0))
    #denormalize
    mean = np.array([0.7180, 0.6071, 0.5638])
    std = np.array([0.1015, 0.1216, 0.1438])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
def visualize_model(model, loader, device, num_images=6):
    """Imshow for Tensor.
       Function to visualize some images and their predictions with the corresponding ground truth labels
       inputs: model => model  to predict the classes  
               loader => PyTorch dataloader to get the images 
               device => CUDA or CPU
               num_images => the number of images to show
       returns: None

    """
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for batch in loader:
            inputs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {preds[j]}')
                imshow(inputs.cpu().data[j])
                print(f'Actual: {labels[j]}, predicted: {preds[j]}')

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## Loss function

# %% [markdown]
# Here we define loss functions that are not available in PyTorch's nn module

# %% [markdown]
# ### Focal Loss

# %%
from torch.autograd import Variable

class FocalLoss(nn.Module):
    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if isinstance(alpha,(float,int)): self.alpha = torch.Tensor([alpha,1-alpha])
        if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)

        logpt = F.log_softmax(input, dim=-1)
        logpt = logpt.gather(1,target)
        logpt = logpt.view(-1)
        pt = Variable(logpt.data.exp())

        if self.alpha is not None:
            if self.alpha.type()!=input.data.type():
                self.alpha = self.alpha.type_as(input.data)
            at = self.alpha.gather(0,target.data.view(-1))
            logpt = logpt * Variable(at)

        loss = -1 * (1-pt)**self.gamma * logpt
        if self.size_average: return loss.mean()
        else: return loss.sum()

# %% [markdown]
# ## Models

# %% [markdown]
# In the following, we create a function that creates an image classification model from torchvision.models and modifies its last layer (the classifier) to have 3 outputs instead of 1000.

# %%
def make_densenet(pretrained = True):
  """ Function to create a DenseNet model with 3 output neurones"""
  model = models.densenet121(pretrained=pretrained)
  num_ftrs = model.classifier.in_features
  # Here the size of each output sample is set to 3, the number of types of lesions that we have.
  model.classifier = nn.Linear(num_ftrs, 3)
  model = model.to(DEVICE)
  return model

# %%
def make_vitb16(pretrained = True):
  """ Function to create a ViT model with 3 output neurones"""
  vit = models.vit_b_16(pretrained = True)
  vit.heads =  nn.Sequential(
    nn.Linear(in_features=768, out_features=3, bias=True) # replace 1000 output layer with 3-output lineaar layer
  )
  vit = vit.to(DEVICE)
  return vit

# %%
def make_convnext(pretrained = True):
  """ Function to create a ConvNeXt model with 3 output neurones"""
  model = models.convnext_small(pretrained=pretrained)
  model.classifier[2] = nn.Linear(in_features=768, out_features=3, bias=True) # replace 1000 output layer with 3-output lineaar layer
  model = model.to(DEVICE)
  return model

# %% [markdown]
# ## Training

# %%
# Training function
def train_model(model, # model to be trained
                dataloaders, # dict of 2 dataloaders one for train another for validation
                criterion, # loss function
                optimizer, # optimization algorithm to be used
                scheduler, # LR scheduler
                early_stop_patience=10, # Early stop if no improvement in the loss after this much epochs
                num_epochs=25, # maximum number of epochs 
                writer_path= ''): # path for tensorboard 
    """ Function to train a model """
    since = time.time()

    writers = {
        'train': SummaryWriter(writer_path + '/log'),
        'val': SummaryWriter(writer_path + '/log_val')
    }

    best_model_wts = copy.deepcopy(model.state_dict()) # initialize best weights with initial model weights
    best_loss = 1e8 # as bad as it gets 
    best_bma = 0.0 # as bad as it gets 
    early_stop_c = 0 # initialize early stopping count

    for epoch in range(num_epochs): # iterate over the whole dataset (epoch)
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']: 
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0 # keep track of epoch loss
            running_labels = [] # list to hold labels over all the epoch
            running_preds = [] # list to hold the model predictions over all the epoch

            # Iterate over data.
            for batch in dataloaders[phase]: # iterate over each batch in the loader

                inputs = batch["image"].to(DEVICE) # fetch data and move to GPU/cPU
                labels = batch["label"].to(DEVICE) # fetch data and move to GPU/cPU

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history only if in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs) # formward pass
                    _, preds = torch.max(outputs, 1) # assume class with max probability as output
                    loss = criterion(outputs, labels) # calculate the loss of the batch

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward() # backpropagation
                        optimizer.step() # update weights 

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_labels = running_labels + labels.int().cpu().tolist()
                running_preds = running_preds + preds.int().cpu().tolist()


            epoch_loss = running_loss / dataset_sizes[phase] # average loss of the epoch
            epoch_acc = accuracy_score(running_labels, running_preds) # accuracy of the epoch
            epoch_bma = balanced_accuracy_score(running_labels, running_preds) # balanced multiclass accuracy of the epoch

            if phase == 'val':
              scheduler.step(epoch_loss) # Update LR dynamically 
              lr_ = optimizer.param_groups[0]['lr'] # save current learning rate to writer
              writers['train'].add_scalar('info/lr', lr_, epoch)

            # print(f'{phase} Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f}, BMA: {epoch_bma:.4f}')
            logging.info( '%s epoch %d : loss : %.4f, acc: %.4f, bma: %.4f' %
                (phase, epoch+1, epoch_loss, epoch_acc, epoch_bma))
            
            # save stats to writer for tracking
            writers[phase].add_scalar('info/loss', epoch_loss, epoch)
            writers[phase].add_scalar('info/acc', epoch_acc, epoch)
            writers[phase].add_scalar('info/bma', epoch_bma, epoch)

            # update best parameters
            if phase == 'val':
              if epoch_loss < best_loss: # a new best val loss achieved 
                best_loss = epoch_loss # update the best loss
                early_stop_c = 0 #new minimum found, reset ES counter
              else:
                early_stop_c += 1 # increment ES counter

              if epoch_bma > best_bma: # new best bma achieved
                best_bma = epoch_bma  # update bma tracker
                best_model_wts = copy.deepcopy(model.state_dict()) # update best weights tracker 

        if early_stop_c > early_stop_patience: # if no val loss minimum was found in the last ES Patience epochs then stop training
            print(f'EARLY STOP AFTER {epoch + 1} EPOCHS')         
            break   

        print()
    # print statistics 
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val loss: {best_loss:4f}')
    print(f"Best val BMA: {best_bma}")

    # load best model weights
    model.load_state_dict(best_model_wts)
    writers['train'].close()
    writers['val'].close()
    return model

# %% [markdown]
# ## Testing

# %%
def test_model(model,  # model to be tested
               loader, # test loader
               device, # Cuda or CPU
               criterion): # loss function

    """ Function to test a model's performance on the test set 
        inputs: model => model to be tested
                loader => test loader 
                device => Cuda or CPU
                criterion => objective function

        returns: test loss, test accuracy and test bma
    """           
    since = time.time()

    model.eval()   # Set model to evaluate mode

    running_loss = 0.0
    running_corrects = 0
    running_labels = []
    running_preds = []

    # Iterate over data.
    with torch.no_grad():
        for batch in loader:
            inputs = batch["image"].to(DEVICE)
            labels = batch["label"].to(DEVICE)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            running_labels = running_labels + labels.int().cpu().tolist()
            running_preds = running_preds + preds.int().cpu().tolist()

        test_loss = running_loss / dataset_sizes['test'] 
        test_bma = balanced_accuracy_score(running_labels, running_preds)
        test_acc = accuracy_score(running_labels, running_preds)
        print(f'Test Loss: {test_loss:.4f} Acc: {test_acc:.4f}, BMA: {test_bma:.4f}')
    
        time_elapsed = time.time() - since
        print(f'Testing complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

        model.train()

        return test_loss, test_acc, test_bma

# %% [markdown]
# # **Dataset Definition and Split**

# %% [markdown]
# ## Sampler

# %% [markdown]
# This is a custom sampler to be passed as a parameter to the dataloader. It randomly samples the dataset to have a balanced number of images in each class. In the 'over' case the new number of images in each class will be equal to the number of images in the 'majority' class (benign). The minority classes will be sampled with replacement, in the case of 'mean' the new number of images in each class will be equal to the 'mean' of the numbers of samples in each class. in the case of 'under' the new number of images in each class will be equal to the number of images in the 'minority' class (seborrheic keratosis).

# %%
from typing import Callable
class ImbalancedDatasetSampler(torch.utils.data.sampler.Sampler):
    """Samples elements randomly from a given list of indices for imbalanced dataset
    Arguments:
        indices: a list of indices
        num_samples: number of samples to draw
        callback_get_label: a callback-like function which takes two arguments - dataset and index
    """

    def __init__(self, dataset, indices: list = None, num_samples: int = None, callback_get_label: Callable = None,
                 replacement=True):
        # if indices is not provided, all elements in the dataset will be considered
        self.indices = list(range(len(dataset))) if indices is None else indices

        # define custom callback
        self.callback_get_label = callback_get_label

        # if num_samples is not provided, draw `len(indices)` samples in each iteration
        self.num_samples = len(self.indices) if num_samples is None else num_samples

        self.replacement = replacement

        # distribution of classes in the dataset
        df = pd.DataFrame()
        df["label"] = self._get_labels(dataset)
        df.index = self.indices
        df = df.sort_index()

        label_to_count = df["label"].value_counts()

        weights = 1.0 / label_to_count[df["label"]]

        self.weights = torch.DoubleTensor(weights.to_list())

    def _get_labels(self, dataset):
        if self.callback_get_label:
            return self.callback_get_label(dataset)
        elif isinstance(dataset, torchvision.datasets.MNIST):
            return dataset.train_labels.tolist()
        elif isinstance(dataset, torchvision.datasets.ImageFolder):
            return [x[1] for x in dataset.imgs]
        elif isinstance(dataset, torchvision.datasets.DatasetFolder):
            return dataset.samples[:][1]
        elif isinstance(dataset, torch.utils.data.Subset):
            return dataset.dataset.imgs[:][1]
        elif isinstance(dataset, torch.utils.data.Dataset):
            return dataset.get_labels()
        else:
            raise NotImplementedError

    def __iter__(self):
        return (self.indices[i] for i in
                torch.multinomial(self.weights, self.num_samples, replacement=self.replacement))

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ## Custom ISIC2017 Dataset

# %% [markdown]
# Next, we create a custom Pytorch dataset class for ISIC2017 data

# %%
# Parameters 
# Please change to the corresponding path if not the same in your device
# Image directories
train_img_folder = '/content/drive/MyDrive/MRTYUTeam/Dataset/images'
val_img_folder = '/content/drive/MyDrive/MRTYUTeam/Dataset/validation_images'
test_img_folder = '/content/drive/MyDrive/MRTYUTeam/Dataset/test_images'

# CSV paths
train_csv_path = '/content/drive/MyDrive/MRTYUTeam/Dataset/train_2000.csv'
val_csv_path = '/content/drive/MyDrive/MRTYUTeam/Dataset/validation_150.csv'
test_csv_path = '/content/drive/MyDrive/MRTYUTeam/Dataset/test_600.csv'

#number of samples in each set
dataset_sizes = {
    'train': 2000,
    'val':150,
    'test':600
}

# %%
class ISIC2017Dataset(Dataset):
    """ISIC2017 dataset"""

    def __init__(self, csv_file, image_folder, img_transform=None, augment = False):
        """
        Args:
            csv_file (string): Path to the csv file with image paths & classification labels.
            image_folder (string): Path to the folder where the PNG images are located
            img_transform (callable, optional): Optional transform to be applied on a sample.
            augment (boolean): Whether to perform data augmentation or not
        """
        self.df = pd.read_csv(csv_file).drop("Unnamed: 0", axis = 1) # pandas dataframe containing the image IDs and classification labels  
        self.image_folder = image_folder # path to the folder containing the original images 
        self.img_transform = img_transform # image transform for the images
        self.augment = augment # whether to perform data augmentation or not
        self.labels = self.df["label"].values.tolist()
        

    def __len__(self):
        return len(self.df) # return the number of images in the dataset

    
    def get_labels(self):
        return self.labels # return the number of images in the dataset


    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
       
        img_id = '/' + self.df.iloc[idx]['image_id'] # obtain image file name start 
        
        img_path = self.image_folder+img_id + '.jpg' # file path of the original image 
        image = Image.open(img_path)  # open the original image as RGB

        label = self.df.iloc[idx]['label'] # get the image's correct class

        # If augment = T perform data augmentation: 
        if self.augment:
          image_np = np.array(image) # albumentations only works with np arrays so convert from PIL 
          aug_transform = A.Compose(
                                      [   
                                          A.SmallestMaxSize(max_size=260),
                                          A.RandomResizedCrop(height=256, width=256, p = 0.7, scale=(0.4, 1.0), ratio=(0.75, 4/3)),
                                          A.Affine(scale=(0.8, 1.2), rotate=(0.0, 90.0), shear=(0.0, 20.0), mode=1, p=0.8),
                                          A.Flip(p=0.9),
                                          A.ColorJitter(brightness=[0.7, 1.3], contrast=[0.7, 1.3], saturation=[0.9, 1.1], hue=0.05, p=0.6),
                                      ]
                                  )
          augmentations = aug_transform(image=image_np) # apply the transform 
          image = Image.fromarray(augmentations["image"]) # convert back to PIL to use torchvision transforms

        # If a transform is provided apply it (Preprocessing)
        if self.img_transform:
            image = self.img_transform(image)

        # return the image, the segmentation label
        return {
            'image': image,
            'label': label,
      }

# %% [markdown]
# ## Prepare data

# %%
# function to find the number of samples in the balanced trainning loader
def get_samples_count(y, sampling_technique):
        """
          function to find the number of samples in the balanced trainning loader
          inputs: y => list of labels 
                  sampling technique => 'mean' or 'over' or 'under'

          returns: mean_samples = 
                                  mean of the number of samples in each class if 'mean'
                                  #samples in the majority class for each class if 'over'
                                  #samples in the minority class for each class if 'under' 
        """
        unique, counts = np.unique(y, return_counts=True) # number of samples in each class
       
        if sampling_technique == 'mean':
            mean_samples = np.mean(counts)*3 # return the mean of samples from each class 
        elif sampling_technique == 'over':
            mean_samples = np.max(counts)*3 # return the #samples in the majority class for each class 
        elif sampling_technique == 'under':
            mean_samples = np.min(counts)*3 # return the #samples in the minority class for each class
        else:
            raise Exception("Error: Sampling Technique not implemented")
        return int(mean_samples)

# %%
# Parameters
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used

NEW_SIZE = 256

# Calculated from the original training set 
mu = [0.7079, 0.5916, 0.5469]# mean
std = [0.0937, 0.1113, 0.1257]# Standard deviation

TRAIN_BATCH_SIZE = 10
TEST_BATCH_SIZE = 64
VAL_BATCH_SIZE = 64
NUM_WORKERS = 2

# %% [markdown]
# #### Data Transforms

# %%
# Transforms for preprocessing, we will use the same for all datasets here
img_transforms = transforms.Compose([
                                      transforms.Resize(NEW_SIZE+4),
                                      transforms.CenterCrop(NEW_SIZE),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean= mu, std=std)
                                  ])

# %% [markdown]
# #### Datasets

# %%
# Training dataset, will contain 3000 images after augmentation
isic_train = ISIC2017Dataset(csv_file=train_csv_path,
                             image_folder= train_img_folder,
                             img_transform = img_transforms,
                             augment = True) # apply data augmentation to the training set

# %%
# Validation dataset, will contain 300 images from the augmented test set
isic_val = ISIC2017Dataset(csv_file=val_csv_path, 
                            image_folder= val_img_folder, 
                            img_transform = img_transforms,
                            augment=False)

# %%
# Test dataset, will contain the original 1000 images from ISIC2017
isic_test = ISIC2017Dataset(csv_file=test_csv_path, 
                            image_folder= test_img_folder, 
                            img_transform = img_transforms,
                            augment=False)

# %% [markdown]
# #### Data Loaders

# %%
# use sklearn to obtain class weights to give more importance to minority classes
y = isic_train.get_labels()
class_weights= class_weight.compute_class_weight(class_weight = 'balanced', classes= np.unique(y), y= np.array(y))
class_weights =  torch.tensor(class_weights).float().to(DEVICE)

# %%
class_weights
# Out:
# tensor([0.4859, 1.7825, 2.6247], device='cuda:0')

# %%
# Balanced training dataloader
mean_samples = get_samples_count(isic_train.get_labels(), 'under') # perform undersampling 
data_sampler = ImbalancedDatasetSampler(isic_train, indices=None, num_samples=mean_samples, replacement = True)
train_loader_balanced = DataLoader(isic_train, sampler=data_sampler, num_workers=NUM_WORKERS,
                             batch_size=TRAIN_BATCH_SIZE)

# %%
mean_samples
# Out:
# 762

# %%
# dataloaders with the original number of samples in the dataset
train_loader = DataLoader(isic_train, batch_size=TRAIN_BATCH_SIZE, num_workers=NUM_WORKERS, shuffle=True)
val_loader = DataLoader(isic_val, batch_size=VAL_BATCH_SIZE, num_workers=NUM_WORKERS)
test_loader = DataLoader(isic_test, batch_size=TEST_BATCH_SIZE, num_workers=NUM_WORKERS)

# %%
dataloaders = {"train": train_loader,
              "val": val_loader}

dataloaders_balanced = {"train": train_loader_balanced,
                        "val": val_loader}

# %%
# Get a batch of training data
batch = next(iter(train_loader_balanced))
inputs = batch["image"]
classes = batch["label"]

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[x.item() for x in classes])

# %% [markdown]
# # Training & Evaluation

# %% [markdown]
# ## 1. DenseNet

# %% [markdown]
# ### Train

# %% [markdown]
# #### With Focal Loss

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/densenest_fl_sgd_2.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4 # base learning rate
LR_PATIENCE = 5 # if no val loss improvement in this much epochs update the LR
ES_PATIENCE = 10 # if no improvement in val loss after this much epochs stop training
EPOCHS = 100 # maximum number of epochs 
WD = 1e-6 # weight decay

# %%
densenet = make_densenet(True) # create the model

criterion = FocalLoss(alpha = class_weights, gamma = 2.0, size_average= True) # use Focal loss with the class weights obtained from sklearn

optimizer = optim.SGD(densenet.parameters(), lr = LR, weight_decay=WD, momentum = 0.9) # use SGD algorithm for optimization

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.25, mode="min") # use dynamic learning rate scheduling

# %%
logging.info('Model:Densenet, LR: 1e-4, LR patience = 5, loss: Focal, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-6, momentum = 0.9')
# Out:
# Model:Densenet, LR: 1e-4, LR patience = 5, loss: Focal, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-6, momentum = 0.9

# %%
# train the model
densenet = train_model(densenet, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.4738, acc: 0.3760, bma: 0.4235
# val epoch 1 : loss : 0.6199, acc: 0.5533, bma: 0.5352
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.4199, acc: 0.4810, bma: 0.5131
# val epoch 2 : loss : 0.5281, acc: 0.5133, bma: 0.5342
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.3908, acc: 0.5100, bma: 0.5590
# val epoch 3 : loss : 0.4963, acc: 0.5400, bma: 0.5718
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.3718, acc: 0.5515, bma: 0.5852
# val epoch 4 : loss : 0.4552, acc: 0.5200, bma: 0.5258
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.3628, acc: 0.5595, bma: 0.5951
# val epoch 5 : loss : 0.4447, acc: 0.6200, bma: 0.6009
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.3423, acc: 0.5740, bma: 0.6145
# val epoch 6 : loss : 0.4386, acc: 0.6533, bma: 0.6295
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.3429, acc: 0.5650, bma: 0.6083
# val epoch 7 : loss : 0.4156, acc: 0.6467, bma: 0.6184
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.3311, acc: 0.6005, bma: 0.6310
# val epoch 8 : loss : 0.3876, acc: 0.6600, bma: 0.6470
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.3268, acc: 0.6145, bma: 0.6438
# val epoch 9 : loss : 0.3843, acc: 0.6867, bma: 0.6709
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.3307, acc: 0.6070, bma: 0.6516
# val epoch 10 : loss : 0.3875, acc: 0.6600, bma: 0.6365
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.3093, acc: 0.6265, bma: 0.6662
# val epoch 11 : loss : 0.3745, acc: 0.6467, bma: 0.6253
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.3062, acc: 0.6165, bma: 0.6559
# val epoch 12 : loss : 0.3725, acc: 0.7267, bma: 0.6897
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.3081, acc: 0.6335, bma: 0.6560
# val epoch 13 : loss : 0.3384, acc: 0.6400, bma: 0.6593
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.2998, acc: 0.6235, bma: 0.6653
# val epoch 14 : loss : 0.3549, acc: 0.7267, bma: 0.6797
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.2987, acc: 0.6285, bma: 0.6636
# val epoch 15 : loss : 0.3337, acc: 0.7267, bma: 0.7071
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.3153, acc: 0.6165, bma: 0.6486
# val epoch 16 : loss : 0.3275, acc: 0.7133, bma: 0.6990
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.3000, acc: 0.6320, bma: 0.6657
# val epoch 17 : loss : 0.3303, acc: 0.6733, bma: 0.6602
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.2903, acc: 0.6360, bma: 0.6768
# val epoch 18 : loss : 0.3206, acc: 0.6667, bma: 0.6491
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.2869, acc: 0.6500, bma: 0.6984
# val epoch 19 : loss : 0.3156, acc: 0.7133, bma: 0.6990
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.2874, acc: 0.6415, bma: 0.6745
# val epoch 20 : loss : 0.3123, acc: 0.7333, bma: 0.7355
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.2765, acc: 0.6435, bma: 0.6788
# val epoch 21 : loss : 0.3125, acc: 0.7200, bma: 0.6791
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.2724, acc: 0.6540, bma: 0.6904
# val epoch 22 : loss : 0.2974, acc: 0.6867, bma: 0.6993
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.2747, acc: 0.6515, bma: 0.7002
# val epoch 23 : loss : 0.3124, acc: 0.7200, bma: 0.6969
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.2669, acc: 0.6470, bma: 0.6926
# val epoch 24 : loss : 0.3164, acc: 0.7467, bma: 0.7136
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.2803, acc: 0.6360, bma: 0.6747
# val epoch 25 : loss : 0.3047, acc: 0.6933, bma: 0.6730
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.2843, acc: 0.6400, bma: 0.6656
# val epoch 26 : loss : 0.2815, acc: 0.7267, bma: 0.7217
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.2647, acc: 0.6675, bma: 0.7009
# val epoch 27 : loss : 0.3027, acc: 0.7267, bma: 0.7112
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.2577, acc: 0.6670, bma: 0.7125
# val epoch 28 : loss : 0.2994, acc: 0.7467, bma: 0.7241
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.2697, acc: 0.6550, bma: 0.7006
# val epoch 29 : loss : 0.3003, acc: 0.7133, bma: 0.7063
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.2634, acc: 0.6620, bma: 0.7051
# val epoch 30 : loss : 0.2862, acc: 0.7467, bma: 0.7446
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.2626, acc: 0.6650, bma: 0.7079
# val epoch 31 : loss : 0.2935, acc: 0.7000, bma: 0.6983
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.2578, acc: 0.6570, bma: 0.6988
# val epoch 32 : loss : 0.2935, acc: 0.7200, bma: 0.6869
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.2501, acc: 0.6705, bma: 0.7107
# val epoch 33 : loss : 0.2781, acc: 0.7200, bma: 0.7038
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.2427, acc: 0.6925, bma: 0.7328
# val epoch 34 : loss : 0.2849, acc: 0.7200, bma: 0.7038
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.2634, acc: 0.6660, bma: 0.7069
# val epoch 35 : loss : 0.2916, acc: 0.7267, bma: 0.7117
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.2504, acc: 0.6840, bma: 0.7199
# val epoch 36 : loss : 0.2861, acc: 0.7200, bma: 0.7070
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.2461, acc: 0.6735, bma: 0.7214
# val epoch 37 : loss : 0.2882, acc: 0.7333, bma: 0.7228
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.2471, acc: 0.6610, bma: 0.6898
# val epoch 38 : loss : 0.2778, acc: 0.7333, bma: 0.7365
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.2441, acc: 0.6875, bma: 0.7252
# val epoch 39 : loss : 0.2762, acc: 0.7333, bma: 0.7192
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.2479, acc: 0.6720, bma: 0.7201
# val epoch 40 : loss : 0.2778, acc: 0.7400, bma: 0.7198
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.2482, acc: 0.6770, bma: 0.7120
# val epoch 41 : loss : 0.2872, acc: 0.7667, bma: 0.7505
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.2448, acc: 0.6770, bma: 0.7206
# val epoch 42 : loss : 0.2783, acc: 0.7333, bma: 0.7328
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.2470, acc: 0.6820, bma: 0.7210
# val epoch 43 : loss : 0.2755, acc: 0.7200, bma: 0.7275
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.2426, acc: 0.6765, bma: 0.7244
# val epoch 44 : loss : 0.2797, acc: 0.7000, bma: 0.6978
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.2390, acc: 0.6795, bma: 0.7162
# val epoch 45 : loss : 0.2722, acc: 0.7333, bma: 0.7328
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.2391, acc: 0.6845, bma: 0.7220
# val epoch 46 : loss : 0.2710, acc: 0.7400, bma: 0.7471
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.2463, acc: 0.6835, bma: 0.7193
# val epoch 47 : loss : 0.2689, acc: 0.7267, bma: 0.7081
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.2388, acc: 0.6870, bma: 0.7269
# val epoch 48 : loss : 0.2746, acc: 0.7200, bma: 0.7106
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.2540, acc: 0.6860, bma: 0.7230
# val epoch 49 : loss : 0.2747, acc: 0.7267, bma: 0.7249
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.2390, acc: 0.6955, bma: 0.7264
# val epoch 50 : loss : 0.2712, acc: 0.7267, bma: 0.7322
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.2376, acc: 0.6735, bma: 0.7236
# val epoch 51 : loss : 0.2689, acc: 0.7600, bma: 0.7468
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.2389, acc: 0.7095, bma: 0.7331
# val epoch 52 : loss : 0.2846, acc: 0.7267, bma: 0.7044
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.2288, acc: 0.7010, bma: 0.7499
# val epoch 53 : loss : 0.2703, acc: 0.7533, bma: 0.7462
#
# Epoch 54/100
# ----------
# train epoch 54 : loss : 0.2325, acc: 0.6775, bma: 0.7227
# val epoch 54 : loss : 0.2731, acc: 0.7333, bma: 0.7123
#
# Epoch 55/100
# ----------
# train epoch 55 : loss : 0.2326, acc: 0.6945, bma: 0.7267
# val epoch 55 : loss : 0.2719, acc: 0.7600, bma: 0.7463
#
# Epoch 56/100
# ----------
# train epoch 56 : loss : 0.2471, acc: 0.6820, bma: 0.7129
# val epoch 56 : loss : 0.2609, acc: 0.7400, bma: 0.7339
#
# Epoch 57/100
# ----------
# train epoch 57 : loss : 0.2457, acc: 0.6820, bma: 0.7183
# val epoch 57 : loss : 0.2852, acc: 0.7467, bma: 0.7209
#
# Epoch 58/100
# ----------
# train epoch 58 : loss : 0.2285, acc: 0.6975, bma: 0.7387
# val epoch 58 : loss : 0.2797, acc: 0.7400, bma: 0.7234
#
# Epoch 59/100
# ----------
# train epoch 59 : loss : 0.2475, acc: 0.6875, bma: 0.7298
# val epoch 59 : loss : 0.2722, acc: 0.7333, bma: 0.7228
#
# Epoch 60/100
# ----------
# train epoch 60 : loss : 0.2319, acc: 0.6965, bma: 0.7365
# val epoch 60 : loss : 0.2700, acc: 0.7400, bma: 0.7339
#
# Epoch 61/100
# ----------
# train epoch 61 : loss : 0.2337, acc: 0.7000, bma: 0.7438
# val epoch 61 : loss : 0.2648, acc: 0.7267, bma: 0.7254
#
# Epoch 62/100
# ----------
# train epoch 62 : loss : 0.2314, acc: 0.7045, bma: 0.7447
# val epoch 62 : loss : 0.2749, acc: 0.7600, bma: 0.7399
#
# Epoch 63/100
# ----------
# train epoch 63 : loss : 0.2354, acc: 0.6780, bma: 0.7352
# val epoch 63 : loss : 0.2782, acc: 0.7467, bma: 0.7241
#
# Epoch 64/100
# ----------
# train epoch 64 : loss : 0.2288, acc: 0.6925, bma: 0.7377
# val epoch 64 : loss : 0.2756, acc: 0.7200, bma: 0.7106
#
# Epoch 65/100
# ----------
# train epoch 65 : loss : 0.2262, acc: 0.6825, bma: 0.7248
# val epoch 65 : loss : 0.2746, acc: 0.7400, bma: 0.7339
#
# Epoch 66/100
# ----------
# train epoch 66 : loss : 0.2427, acc: 0.6995, bma: 0.7255
# val epoch 66 : loss : 0.2770, acc: 0.7667, bma: 0.7611
#
# Epoch 67/100
# ----------
# train epoch 67 : loss : 0.2367, acc: 0.6855, bma: 0.7213
# val epoch 67 : loss : 0.2828, acc: 0.7667, bma: 0.7374
# EARLY STOP AFTER 67 EPOCHS
# Training complete in 337m 3s
# Best val loss: 0.260897
# Best val BMA: 0.761050061050061

# %% [markdown]
# Test

# %%
# calculate loss, acc and bma on the test set
test_loss, test_acc, test_bma = test_model(densenet, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.3083 Acc: 0.6433, BMA: 0.6839
# Testing complete in 3m 36s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.3083, acc: 0.6433, bma: 0.6839

# %% [markdown]
# Show some results

# %%
# show some example results 
visualize_model(densenet, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/densenest_fl_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 7
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
densenet = make_densenet(True)

criterion = FocalLoss(alpha = class_weights, gamma = 2.0, size_average= True)

optimizer = optim.Adam(densenet.parameters(), lr = LR, weight_decay=WD) # use Adam optimization algorithm instead of SGD

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model:Densenet, LR: 1e-4, LR patience = 7, loss: Focal, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8')
# Out:
# Model:Densenet, LR: 1e-4, LR patience = 7, loss: Focal, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8

# %%
densenet = train_model(densenet, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.3960, acc: 0.5155, bma: 0.5456
# val epoch 1 : loss : 0.4119, acc: 0.6333, bma: 0.5835
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.3366, acc: 0.5790, bma: 0.6013
# val epoch 2 : loss : 0.3982, acc: 0.6933, bma: 0.6811
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.3000, acc: 0.6100, bma: 0.6549
# val epoch 3 : loss : 0.3281, acc: 0.7133, bma: 0.7154
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.2955, acc: 0.6145, bma: 0.6562
# val epoch 4 : loss : 0.2977, acc: 0.6867, bma: 0.7083
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.2630, acc: 0.6595, bma: 0.7002
# val epoch 5 : loss : 0.2689, acc: 0.7267, bma: 0.7254
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.2426, acc: 0.6670, bma: 0.7073
# val epoch 6 : loss : 0.2426, acc: 0.7667, bma: 0.7574
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.2481, acc: 0.6600, bma: 0.7018
# val epoch 7 : loss : 0.2693, acc: 0.7533, bma: 0.7147
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.2565, acc: 0.6710, bma: 0.7119
# val epoch 8 : loss : 0.2445, acc: 0.7533, bma: 0.7593
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.2278, acc: 0.7075, bma: 0.7446
# val epoch 9 : loss : 0.2213, acc: 0.7867, bma: 0.7770
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.2184, acc: 0.6935, bma: 0.7372
# val epoch 10 : loss : 0.2128, acc: 0.7400, bma: 0.7508
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.2215, acc: 0.7125, bma: 0.7533
# val epoch 11 : loss : 0.3681, acc: 0.6867, bma: 0.6109
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.2196, acc: 0.7030, bma: 0.7293
# val epoch 12 : loss : 0.2488, acc: 0.7067, bma: 0.7094
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.2052, acc: 0.7120, bma: 0.7530
# val epoch 13 : loss : 0.2162, acc: 0.7867, bma: 0.7880
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.2068, acc: 0.7185, bma: 0.7600
# val epoch 14 : loss : 0.3896, acc: 0.5933, bma: 0.5957
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.2184, acc: 0.7065, bma: 0.7504
# val epoch 15 : loss : 0.2341, acc: 0.7667, bma: 0.7332
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.1946, acc: 0.7195, bma: 0.7674
# val epoch 16 : loss : 0.2939, acc: 0.6667, bma: 0.7006
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.2063, acc: 0.7185, bma: 0.7648
# val epoch 17 : loss : 0.3008, acc: 0.6400, bma: 0.6525
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.1932, acc: 0.7285, bma: 0.7559
# val epoch 18 : loss : 0.2316, acc: 0.7667, bma: 0.7264
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.1606, acc: 0.7625, bma: 0.8084
# val epoch 19 : loss : 0.2124, acc: 0.7667, bma: 0.7716
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.1431, acc: 0.7740, bma: 0.8247
# val epoch 20 : loss : 0.1946, acc: 0.7933, bma: 0.8023
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.1287, acc: 0.8030, bma: 0.8398
# val epoch 21 : loss : 0.1986, acc: 0.7800, bma: 0.7769
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.1266, acc: 0.8080, bma: 0.8417
# val epoch 22 : loss : 0.1610, acc: 0.7933, bma: 0.8192
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.1259, acc: 0.8235, bma: 0.8651
# val epoch 23 : loss : 0.1916, acc: 0.7867, bma: 0.7949
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.1211, acc: 0.8285, bma: 0.8647
# val epoch 24 : loss : 0.1840, acc: 0.7600, bma: 0.7673
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.1244, acc: 0.8125, bma: 0.8438
# val epoch 25 : loss : 0.1964, acc: 0.7867, bma: 0.7770
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.1404, acc: 0.7930, bma: 0.8279
# val epoch 26 : loss : 0.2774, acc: 0.7267, bma: 0.7149
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.1139, acc: 0.8140, bma: 0.8594
# val epoch 27 : loss : 0.2005, acc: 0.8000, bma: 0.7788
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.1146, acc: 0.8075, bma: 0.8459
# val epoch 28 : loss : 0.1780, acc: 0.8400, bma: 0.8391
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.1052, acc: 0.8260, bma: 0.8696
# val epoch 29 : loss : 0.2169, acc: 0.7733, bma: 0.7753
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.1066, acc: 0.8345, bma: 0.8616
# val epoch 30 : loss : 0.1664, acc: 0.7933, bma: 0.8092
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.1034, acc: 0.8325, bma: 0.8716
# val epoch 31 : loss : 0.1709, acc: 0.8067, bma: 0.8277
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.0917, acc: 0.8665, bma: 0.8935
# val epoch 32 : loss : 0.1745, acc: 0.7667, bma: 0.7716
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.0963, acc: 0.8470, bma: 0.8802
# val epoch 33 : loss : 0.1569, acc: 0.8000, bma: 0.8029
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.0875, acc: 0.8615, bma: 0.8924
# val epoch 34 : loss : 0.1604, acc: 0.8133, bma: 0.8115
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.0863, acc: 0.8675, bma: 0.9037
# val epoch 35 : loss : 0.2105, acc: 0.7867, bma: 0.7392
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.0759, acc: 0.8745, bma: 0.9066
# val epoch 36 : loss : 0.1781, acc: 0.8133, bma: 0.8115
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.0826, acc: 0.8770, bma: 0.9045
# val epoch 37 : loss : 0.2151, acc: 0.7800, bma: 0.7491
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.0854, acc: 0.8605, bma: 0.8981
# val epoch 38 : loss : 0.1443, acc: 0.8000, bma: 0.8066
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.0738, acc: 0.8860, bma: 0.9095
# val epoch 39 : loss : 0.1723, acc: 0.8067, bma: 0.7698
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.0854, acc: 0.8690, bma: 0.8971
# val epoch 40 : loss : 0.1784, acc: 0.8133, bma: 0.7978
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.0798, acc: 0.8645, bma: 0.8973
# val epoch 41 : loss : 0.1836, acc: 0.8333, bma: 0.8106
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.0776, acc: 0.8720, bma: 0.9020
# val epoch 42 : loss : 0.1689, acc: 0.8400, bma: 0.8186
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.0716, acc: 0.8760, bma: 0.9079
# val epoch 43 : loss : 0.1911, acc: 0.8400, bma: 0.8049
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.0719, acc: 0.8755, bma: 0.9048
# val epoch 44 : loss : 0.1606, acc: 0.8267, bma: 0.8305
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.0646, acc: 0.8945, bma: 0.9263
# val epoch 45 : loss : 0.1417, acc: 0.8267, bma: 0.8063
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.0703, acc: 0.8875, bma: 0.9175
# val epoch 46 : loss : 0.1495, acc: 0.8267, bma: 0.8164
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.0684, acc: 0.8785, bma: 0.9091
# val epoch 47 : loss : 0.2048, acc: 0.7933, bma: 0.7818
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.0655, acc: 0.9005, bma: 0.9296
# val epoch 48 : loss : 0.1543, acc: 0.8133, bma: 0.8046
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.0633, acc: 0.8965, bma: 0.9189
# val epoch 49 : loss : 0.1607, acc: 0.8400, bma: 0.8459
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.0650, acc: 0.8870, bma: 0.9160
# val epoch 50 : loss : 0.1750, acc: 0.8333, bma: 0.8275
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.0652, acc: 0.8875, bma: 0.9084
# val epoch 51 : loss : 0.1905, acc: 0.8667, bma: 0.8525
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.0673, acc: 0.8980, bma: 0.9248
# val epoch 52 : loss : 0.2151, acc: 0.8200, bma: 0.7916
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.0623, acc: 0.8985, bma: 0.9199
# val epoch 53 : loss : 0.2048, acc: 0.8400, bma: 0.8181
#
# Epoch 54/100
# ----------
# train epoch 54 : loss : 0.0572, acc: 0.8905, bma: 0.9216
# val epoch 54 : loss : 0.1803, acc: 0.8400, bma: 0.8454
#
# Epoch 55/100
# ----------
# train epoch 55 : loss : 0.0564, acc: 0.9080, bma: 0.9299
# val epoch 55 : loss : 0.1864, acc: 0.8267, bma: 0.8269
#
# Epoch 56/100
# ----------
# train epoch 56 : loss : 0.0534, acc: 0.9130, bma: 0.9364
# val epoch 56 : loss : 0.1799, acc: 0.7933, bma: 0.7918
# EARLY STOP AFTER 56 EPOCHS
# Training complete in 275m 4s
# Best val loss: 0.141744
# Best val BMA: 0.8525030525030525

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(densenet, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.3792 Acc: 0.7700, BMA: 0.7275
# Testing complete in 3m 25s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.3792, acc: 0.7700, bma: 0.7275

# %% [markdown]
# Show some results

# %%
visualize_model(densenet, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 0
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 0
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 0
# Actual: 2, predicted: 1

# %% [markdown]
# #### With Weighted Cross Entropy

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/densenest_wce_sgd.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 7
ES_PATIENCE = 15

EPOCHS = 100
WD = 1e-8

# %%
densenet = make_densenet(True)

criterion = nn.CrossEntropyLoss(weight=class_weights) # use Weighted cross entropy loss instead of focal loss

optimizer = optim.SGD(densenet.parameters(), lr = LR, weight_decay=WD, momentum = 0.9)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model:Densenet, LR init: 1e-4, LR patience = 7, loss: WCE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9')
# Out:
# Model:Densenet, LR init: 1e-4, LR patience = 7, loss: WCE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9

# %%
densenet = train_model(densenet, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 1.0448, acc: 0.5015, bma: 0.4481
# val epoch 1 : loss : 0.9862, acc: 0.5667, bma: 0.5359
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.9292, acc: 0.5890, bma: 0.5671
# val epoch 2 : loss : 0.9095, acc: 0.6533, bma: 0.5819
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.8673, acc: 0.6205, bma: 0.5829
# val epoch 3 : loss : 0.7669, acc: 0.6467, bma: 0.6238
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.8222, acc: 0.6305, bma: 0.6251
# val epoch 4 : loss : 0.7170, acc: 0.7000, bma: 0.6531
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.8082, acc: 0.6565, bma: 0.6472
# val epoch 5 : loss : 0.6640, acc: 0.6333, bma: 0.6336
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.7646, acc: 0.6635, bma: 0.6650
# val epoch 6 : loss : 0.6253, acc: 0.6533, bma: 0.6437
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.7373, acc: 0.6925, bma: 0.6980
# val epoch 7 : loss : 0.5918, acc: 0.7133, bma: 0.7059
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.7177, acc: 0.6820, bma: 0.6942
# val epoch 8 : loss : 0.5891, acc: 0.7467, bma: 0.7162
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.7212, acc: 0.6800, bma: 0.6735
# val epoch 9 : loss : 0.5508, acc: 0.7400, bma: 0.7498
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.6775, acc: 0.6905, bma: 0.7027
# val epoch 10 : loss : 0.5091, acc: 0.7400, bma: 0.7471
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.6846, acc: 0.7170, bma: 0.7084
# val epoch 11 : loss : 0.5115, acc: 0.7333, bma: 0.7292
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.6703, acc: 0.7010, bma: 0.7006
# val epoch 12 : loss : 0.5166, acc: 0.7267, bma: 0.7217
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.6740, acc: 0.6870, bma: 0.6956
# val epoch 13 : loss : 0.5407, acc: 0.7533, bma: 0.7247
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.6365, acc: 0.7095, bma: 0.7213
# val epoch 14 : loss : 0.4834, acc: 0.7400, bma: 0.7203
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.6319, acc: 0.7125, bma: 0.7200
# val epoch 15 : loss : 0.4778, acc: 0.7733, bma: 0.7343
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.6099, acc: 0.7210, bma: 0.7374
# val epoch 16 : loss : 0.4778, acc: 0.7400, bma: 0.7198
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.6091, acc: 0.7035, bma: 0.7265
# val epoch 17 : loss : 0.4894, acc: 0.7333, bma: 0.7087
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.6074, acc: 0.7285, bma: 0.7297
# val epoch 18 : loss : 0.4617, acc: 0.7533, bma: 0.7420
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.6073, acc: 0.7355, bma: 0.7367
# val epoch 19 : loss : 0.4659, acc: 0.7533, bma: 0.7393
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.5931, acc: 0.7460, bma: 0.7453
# val epoch 20 : loss : 0.4655, acc: 0.7733, bma: 0.7726
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.5807, acc: 0.7390, bma: 0.7553
# val epoch 21 : loss : 0.4633, acc: 0.7600, bma: 0.7504
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.5501, acc: 0.7540, bma: 0.7595
# val epoch 22 : loss : 0.4988, acc: 0.7267, bma: 0.7149
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.5415, acc: 0.7545, bma: 0.7717
# val epoch 23 : loss : 0.4930, acc: 0.7667, bma: 0.7232
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.5471, acc: 0.7640, bma: 0.7731
# val epoch 24 : loss : 0.5371, acc: 0.7667, bma: 0.7427
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.5277, acc: 0.7695, bma: 0.7809
# val epoch 25 : loss : 0.4723, acc: 0.7600, bma: 0.7495
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.5310, acc: 0.7645, bma: 0.7814
# val epoch 26 : loss : 0.4629, acc: 0.7800, bma: 0.7728
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.5190, acc: 0.7740, bma: 0.7830
# val epoch 27 : loss : 0.4554, acc: 0.7667, bma: 0.7642
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.5045, acc: 0.7800, bma: 0.7868
# val epoch 28 : loss : 0.4668, acc: 0.7867, bma: 0.7907
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.5525, acc: 0.7580, bma: 0.7707
# val epoch 29 : loss : 0.4614, acc: 0.7400, bma: 0.7440
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.4939, acc: 0.7810, bma: 0.7937
# val epoch 30 : loss : 0.4630, acc: 0.7800, bma: 0.7828
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.4987, acc: 0.7695, bma: 0.7823
# val epoch 31 : loss : 0.4884, acc: 0.7267, bma: 0.7249
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.5050, acc: 0.7735, bma: 0.7855
# val epoch 32 : loss : 0.4733, acc: 0.7867, bma: 0.7802
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.4884, acc: 0.7860, bma: 0.7961
# val epoch 33 : loss : 0.4634, acc: 0.7600, bma: 0.7631
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.4921, acc: 0.7780, bma: 0.7950
# val epoch 34 : loss : 0.4648, acc: 0.7533, bma: 0.7589
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.4505, acc: 0.7970, bma: 0.8057
# val epoch 35 : loss : 0.4834, acc: 0.7467, bma: 0.7099
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.4852, acc: 0.7875, bma: 0.7988
# val epoch 36 : loss : 0.4839, acc: 0.7600, bma: 0.7189
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.4501, acc: 0.8020, bma: 0.8136
# val epoch 37 : loss : 0.4647, acc: 0.7467, bma: 0.7140
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.4604, acc: 0.7820, bma: 0.8021
# val epoch 38 : loss : 0.4714, acc: 0.7533, bma: 0.7320
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.4617, acc: 0.7980, bma: 0.8127
# val epoch 39 : loss : 0.4407, acc: 0.7867, bma: 0.7839
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.4543, acc: 0.7985, bma: 0.8099
# val epoch 40 : loss : 0.4439, acc: 0.7867, bma: 0.7802
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.4562, acc: 0.7920, bma: 0.8104
# val epoch 41 : loss : 0.4385, acc: 0.7867, bma: 0.7976
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.4494, acc: 0.8045, bma: 0.8145
# val epoch 42 : loss : 0.4543, acc: 0.7733, bma: 0.7748
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.4503, acc: 0.8040, bma: 0.8220
# val epoch 43 : loss : 0.4278, acc: 0.7800, bma: 0.7728
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.4381, acc: 0.8070, bma: 0.8177
# val epoch 44 : loss : 0.4457, acc: 0.7667, bma: 0.7574
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.4444, acc: 0.8070, bma: 0.8242
# val epoch 45 : loss : 0.4782, acc: 0.7800, bma: 0.7718
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.4632, acc: 0.7795, bma: 0.7989
# val epoch 46 : loss : 0.4488, acc: 0.7800, bma: 0.7759
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.4520, acc: 0.8010, bma: 0.8140
# val epoch 47 : loss : 0.4460, acc: 0.7867, bma: 0.7834
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.4484, acc: 0.8025, bma: 0.8076
# val epoch 48 : loss : 0.4283, acc: 0.7867, bma: 0.7871
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.4537, acc: 0.8020, bma: 0.8146
# val epoch 49 : loss : 0.4178, acc: 0.7800, bma: 0.7896
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.4467, acc: 0.8095, bma: 0.8200
# val epoch 50 : loss : 0.4126, acc: 0.7867, bma: 0.7907
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.4464, acc: 0.7985, bma: 0.8144
# val epoch 51 : loss : 0.4289, acc: 0.7733, bma: 0.7722
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.4143, acc: 0.8165, bma: 0.8309
# val epoch 52 : loss : 0.4292, acc: 0.8000, bma: 0.8061
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.4249, acc: 0.8045, bma: 0.8143
# val epoch 53 : loss : 0.4913, acc: 0.7800, bma: 0.7623
#
# Epoch 54/100
# ----------
# train epoch 54 : loss : 0.4260, acc: 0.8030, bma: 0.8289
# val epoch 54 : loss : 0.4170, acc: 0.7800, bma: 0.7728
#
# Epoch 55/100
# ----------
# train epoch 55 : loss : 0.4229, acc: 0.8070, bma: 0.8192
# val epoch 55 : loss : 0.4439, acc: 0.7800, bma: 0.7696
#
# Epoch 56/100
# ----------
# train epoch 56 : loss : 0.4016, acc: 0.8080, bma: 0.8308
# val epoch 56 : loss : 0.4661, acc: 0.7733, bma: 0.7748
#
# Epoch 57/100
# ----------
# train epoch 57 : loss : 0.4413, acc: 0.8015, bma: 0.8107
# val epoch 57 : loss : 0.4753, acc: 0.7800, bma: 0.7759
#
# Epoch 58/100
# ----------
# train epoch 58 : loss : 0.4189, acc: 0.8240, bma: 0.8386
# val epoch 58 : loss : 0.5161, acc: 0.7800, bma: 0.7549
#
# Epoch 59/100
# ----------
# train epoch 59 : loss : 0.4317, acc: 0.8125, bma: 0.8259
# val epoch 59 : loss : 0.4570, acc: 0.7800, bma: 0.7823
#
# Epoch 60/100
# ----------
# train epoch 60 : loss : 0.4259, acc: 0.8080, bma: 0.8265
# val epoch 60 : loss : 0.4287, acc: 0.7667, bma: 0.7742
#
# Epoch 61/100
# ----------
# train epoch 61 : loss : 0.4131, acc: 0.8195, bma: 0.8397
# val epoch 61 : loss : 0.4409, acc: 0.7867, bma: 0.7907
#
# Epoch 62/100
# ----------
# train epoch 62 : loss : 0.4033, acc: 0.8160, bma: 0.8360
# val epoch 62 : loss : 0.4327, acc: 0.7600, bma: 0.7600
#
# Epoch 63/100
# ----------
# train epoch 63 : loss : 0.4294, acc: 0.8135, bma: 0.8303
# val epoch 63 : loss : 0.4299, acc: 0.7867, bma: 0.8007
#
# Epoch 64/100
# ----------
# train epoch 64 : loss : 0.3963, acc: 0.8230, bma: 0.8418
# val epoch 64 : loss : 0.4342, acc: 0.7667, bma: 0.7606
#
# Epoch 65/100
# ----------
# train epoch 65 : loss : 0.4081, acc: 0.8180, bma: 0.8351
# val epoch 65 : loss : 0.4381, acc: 0.7800, bma: 0.7896
#
# Epoch 66/100
# ----------
# train epoch 66 : loss : 0.4095, acc: 0.8200, bma: 0.8341
# val epoch 66 : loss : 0.4262, acc: 0.7800, bma: 0.7764
# EARLY STOP AFTER 66 EPOCHS
# Training complete in 332m 37s
# Best val loss: 0.412557
# Best val BMA: 0.8061050061050062

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(densenet, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.7014 Acc: 0.7000, BMA: 0.7319
# Testing complete in 3m 26s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.7014, acc: 0.7000, bma: 0.7319

# %% [markdown]
# Show some results

# %%
visualize_model(densenet, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 1
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/densenest_wce_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 7
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
densenet = make_densenet(True)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(densenet.parameters(), lr = LR, weight_decay=WD)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model:Densenet, LR: 1e-4, LR patience = 7, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8')
# Out:
# Model:Densenet, LR: 1e-4, LR patience = 7, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8

# %%
densenet = train_model(densenet, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.9105, acc: 0.5690, bma: 0.5805
# val epoch 1 : loss : 0.7570, acc: 0.7267, bma: 0.6897
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.7446, acc: 0.6570, bma: 0.6704
# val epoch 2 : loss : 0.6180, acc: 0.7067, bma: 0.7194
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.7197, acc: 0.6865, bma: 0.6870
# val epoch 3 : loss : 0.7017, acc: 0.7267, bma: 0.6497
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.6648, acc: 0.6980, bma: 0.7099
# val epoch 4 : loss : 0.5997, acc: 0.7133, bma: 0.7076
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.6755, acc: 0.7075, bma: 0.7061
# val epoch 5 : loss : 0.4807, acc: 0.6800, bma: 0.6886
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.6520, acc: 0.7030, bma: 0.7103
# val epoch 6 : loss : 0.5495, acc: 0.7000, bma: 0.6504
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.6189, acc: 0.7075, bma: 0.7257
# val epoch 7 : loss : 0.5221, acc: 0.7333, bma: 0.6781
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.5907, acc: 0.7425, bma: 0.7481
# val epoch 8 : loss : 0.4679, acc: 0.7600, bma: 0.7563
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.5645, acc: 0.7400, bma: 0.7523
# val epoch 9 : loss : 0.5227, acc: 0.8267, bma: 0.7858
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.5255, acc: 0.7800, bma: 0.7939
# val epoch 10 : loss : 0.5473, acc: 0.8067, bma: 0.7662
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.5533, acc: 0.7435, bma: 0.7582
# val epoch 11 : loss : 0.4572, acc: 0.8133, bma: 0.8015
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.5139, acc: 0.7755, bma: 0.7885
# val epoch 12 : loss : 0.4877, acc: 0.7867, bma: 0.7602
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.4973, acc: 0.7690, bma: 0.7870
# val epoch 13 : loss : 0.5130, acc: 0.7933, bma: 0.7271
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.4763, acc: 0.7895, bma: 0.8100
# val epoch 14 : loss : 0.4406, acc: 0.8200, bma: 0.7889
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.4860, acc: 0.7805, bma: 0.8038
# val epoch 15 : loss : 0.4548, acc: 0.6933, bma: 0.7341
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.4786, acc: 0.7785, bma: 0.8047
# val epoch 16 : loss : 0.4120, acc: 0.7800, bma: 0.7901
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.4858, acc: 0.7725, bma: 0.7917
# val epoch 17 : loss : 0.5583, acc: 0.7600, bma: 0.7426
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.4731, acc: 0.7865, bma: 0.8002
# val epoch 18 : loss : 0.5440, acc: 0.6867, bma: 0.6824
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.4618, acc: 0.7810, bma: 0.7984
# val epoch 19 : loss : 0.4374, acc: 0.7800, bma: 0.7796
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.4369, acc: 0.8005, bma: 0.8255
# val epoch 20 : loss : 0.4523, acc: 0.8133, bma: 0.7810
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.4156, acc: 0.8060, bma: 0.8213
# val epoch 21 : loss : 0.6302, acc: 0.7467, bma: 0.6725
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.3872, acc: 0.8155, bma: 0.8408
# val epoch 22 : loss : 0.4831, acc: 0.8000, bma: 0.7609
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.3783, acc: 0.8260, bma: 0.8439
# val epoch 23 : loss : 0.4720, acc: 0.8200, bma: 0.8016
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.4214, acc: 0.8100, bma: 0.8234
# val epoch 24 : loss : 0.3674, acc: 0.8200, bma: 0.8158
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.4174, acc: 0.8135, bma: 0.8338
# val epoch 25 : loss : 0.6651, acc: 0.7667, bma: 0.7664
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.3907, acc: 0.8255, bma: 0.8399
# val epoch 26 : loss : 0.6037, acc: 0.7867, bma: 0.7934
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.3868, acc: 0.8290, bma: 0.8381
# val epoch 27 : loss : 0.5767, acc: 0.8067, bma: 0.7515
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.3572, acc: 0.8320, bma: 0.8539
# val epoch 28 : loss : 0.5757, acc: 0.8467, bma: 0.7977
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.3842, acc: 0.8325, bma: 0.8497
# val epoch 29 : loss : 0.5386, acc: 0.8133, bma: 0.7973
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.3279, acc: 0.8515, bma: 0.8709
# val epoch 30 : loss : 0.4281, acc: 0.8467, bma: 0.8397
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.3411, acc: 0.8415, bma: 0.8573
# val epoch 31 : loss : 0.5312, acc: 0.7733, bma: 0.7880
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.3390, acc: 0.8380, bma: 0.8601
# val epoch 32 : loss : 0.5196, acc: 0.8067, bma: 0.8067
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.2917, acc: 0.8695, bma: 0.8905
# val epoch 33 : loss : 0.4823, acc: 0.8133, bma: 0.7873
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.2566, acc: 0.8860, bma: 0.9024
# val epoch 34 : loss : 0.4277, acc: 0.8267, bma: 0.7958
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.2619, acc: 0.8845, bma: 0.9034
# val epoch 35 : loss : 0.4962, acc: 0.8067, bma: 0.7930
# EARLY STOP AFTER 35 EPOCHS
# Training complete in 172m 53s
# Best val loss: 0.367412
# Best val BMA: 0.8396825396825397

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(densenet, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.7558 Acc: 0.7417, BMA: 0.7351
# Testing complete in 3m 26s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.7558, acc: 0.7417, bma: 0.7351

# %% [markdown]
# Show some results

# %%
visualize_model(densenet, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 1
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 2
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2

# %% [markdown]
# #### With Sampling + Cross Entropy

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/densenest_ce_sgd.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 7
ES_PATIENCE = 15

EPOCHS = 100
WD = 1e-8

# %%
densenet = make_densenet(True)

criterion = nn.CrossEntropyLoss() # use cross entropy with balanced training loader, no weights

optimizer = optim.SGD(densenet.parameters(), lr = LR, weight_decay=WD, momentum = 0.9)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model:Densenet, LR init: 1e-4, LR patience = 7, loss: CE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9, with Undersampling')
# Out:
# Model:Densenet, LR init: 1e-4, LR patience = 7, loss: CE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9, with Undersampling

# %%
densenet = train_model(densenet, dataloaders_balanced, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.4141, acc: 0.4304, bma: 0.4234
# val epoch 1 : loss : 1.0785, acc: 0.4200, bma: 0.3972
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.3875, acc: 0.4554, bma: 0.4533
# val epoch 2 : loss : 0.9921, acc: 0.5467, bma: 0.5136
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.3708, acc: 0.5538, bma: 0.5532
# val epoch 3 : loss : 0.9262, acc: 0.6067, bma: 0.5462
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.3469, acc: 0.6050, bma: 0.6025
# val epoch 4 : loss : 0.9058, acc: 0.5933, bma: 0.5791
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.3470, acc: 0.5761, bma: 0.5786
# val epoch 5 : loss : 0.8652, acc: 0.6267, bma: 0.6173
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.3334, acc: 0.5840, bma: 0.5842
# val epoch 6 : loss : 0.8734, acc: 0.6000, bma: 0.6017
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.3181, acc: 0.6325, bma: 0.6320
# val epoch 7 : loss : 0.8237, acc: 0.6467, bma: 0.6275
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.3204, acc: 0.6037, bma: 0.6042
# val epoch 8 : loss : 0.7637, acc: 0.6800, bma: 0.6278
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.3147, acc: 0.6168, bma: 0.6174
# val epoch 9 : loss : 0.7409, acc: 0.6733, bma: 0.6099
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.3008, acc: 0.6693, bma: 0.6650
# val epoch 10 : loss : 0.7856, acc: 0.6267, bma: 0.5915
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.3007, acc: 0.6614, bma: 0.6618
# val epoch 11 : loss : 0.7218, acc: 0.7000, bma: 0.6722
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.2992, acc: 0.6299, bma: 0.6278
# val epoch 12 : loss : 0.7776, acc: 0.6733, bma: 0.6629
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.2861, acc: 0.6824, bma: 0.6803
# val epoch 13 : loss : 0.7372, acc: 0.6933, bma: 0.6852
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.2883, acc: 0.6759, bma: 0.6727
# val epoch 14 : loss : 0.7317, acc: 0.6733, bma: 0.6756
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.3001, acc: 0.6339, bma: 0.6349
# val epoch 15 : loss : 0.7348, acc: 0.6467, bma: 0.6385
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.2792, acc: 0.6837, bma: 0.6755
# val epoch 16 : loss : 0.7004, acc: 0.6933, bma: 0.6821
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.2790, acc: 0.6798, bma: 0.6744
# val epoch 17 : loss : 0.7225, acc: 0.6733, bma: 0.6560
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.2702, acc: 0.6929, bma: 0.6847
# val epoch 18 : loss : 0.6782, acc: 0.6800, bma: 0.6325
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.2757, acc: 0.7008, bma: 0.6974
# val epoch 19 : loss : 0.6730, acc: 0.6933, bma: 0.6520
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.2866, acc: 0.6732, bma: 0.6675
# val epoch 20 : loss : 0.6369, acc: 0.7333, bma: 0.7118
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.2658, acc: 0.6837, bma: 0.6834
# val epoch 21 : loss : 0.6415, acc: 0.7333, bma: 0.7219
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.2686, acc: 0.6837, bma: 0.6779
# val epoch 22 : loss : 0.6301, acc: 0.7200, bma: 0.6750
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.2723, acc: 0.6811, bma: 0.6810
# val epoch 23 : loss : 0.6463, acc: 0.7067, bma: 0.6947
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.2685, acc: 0.6929, bma: 0.6931
# val epoch 24 : loss : 0.6663, acc: 0.7067, bma: 0.6811
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.2678, acc: 0.6837, bma: 0.6813
# val epoch 25 : loss : 0.6602, acc: 0.7067, bma: 0.6943
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.2521, acc: 0.7113, bma: 0.7100
# val epoch 26 : loss : 0.6532, acc: 0.7000, bma: 0.6700
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.2577, acc: 0.7060, bma: 0.7065
# val epoch 27 : loss : 0.6842, acc: 0.6467, bma: 0.6626
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.2581, acc: 0.7165, bma: 0.7204
# val epoch 28 : loss : 0.6116, acc: 0.7400, bma: 0.7361
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.2627, acc: 0.6955, bma: 0.6920
# val epoch 29 : loss : 0.6153, acc: 0.7400, bma: 0.7056
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.2540, acc: 0.7152, bma: 0.7163
# val epoch 30 : loss : 0.6444, acc: 0.7467, bma: 0.7172
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.2623, acc: 0.7060, bma: 0.7041
# val epoch 31 : loss : 0.6390, acc: 0.7333, bma: 0.7087
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.2375, acc: 0.7349, bma: 0.7335
# val epoch 32 : loss : 0.6212, acc: 0.7400, bma: 0.7266
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.2520, acc: 0.7231, bma: 0.7206
# val epoch 33 : loss : 0.5845, acc: 0.7667, bma: 0.7369
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.2545, acc: 0.7060, bma: 0.7066
# val epoch 34 : loss : 0.5953, acc: 0.7733, bma: 0.7543
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.2342, acc: 0.7349, bma: 0.7383
# val epoch 35 : loss : 0.6655, acc: 0.7067, bma: 0.7216
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.2438, acc: 0.7323, bma: 0.7297
# val epoch 36 : loss : 0.5991, acc: 0.7667, bma: 0.7542
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.2287, acc: 0.7467, bma: 0.7458
# val epoch 37 : loss : 0.5887, acc: 0.7600, bma: 0.7463
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.2331, acc: 0.7192, bma: 0.7185
# val epoch 38 : loss : 0.5906, acc: 0.7600, bma: 0.7248
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.2422, acc: 0.7441, bma: 0.7434
# val epoch 39 : loss : 0.5961, acc: 0.7667, bma: 0.7496
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.2480, acc: 0.7231, bma: 0.7220
# val epoch 40 : loss : 0.5663, acc: 0.7867, bma: 0.7597
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.2354, acc: 0.7297, bma: 0.7265
# val epoch 41 : loss : 0.5662, acc: 0.7667, bma: 0.7400
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.2322, acc: 0.7270, bma: 0.7280
# val epoch 42 : loss : 0.5975, acc: 0.7733, bma: 0.7585
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.2281, acc: 0.7612, bma: 0.7575
# val epoch 43 : loss : 0.5480, acc: 0.8133, bma: 0.7973
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.2273, acc: 0.7493, bma: 0.7504
# val epoch 44 : loss : 0.5503, acc: 0.8067, bma: 0.7698
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.2191, acc: 0.7572, bma: 0.7546
# val epoch 45 : loss : 0.5630, acc: 0.8067, bma: 0.7904
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.2313, acc: 0.7428, bma: 0.7397
# val epoch 46 : loss : 0.5420, acc: 0.8000, bma: 0.7724
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.2105, acc: 0.7533, bma: 0.7494
# val epoch 47 : loss : 0.5446, acc: 0.7933, bma: 0.7740
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.2112, acc: 0.7677, bma: 0.7680
# val epoch 48 : loss : 0.5751, acc: 0.7600, bma: 0.7536
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.2297, acc: 0.7310, bma: 0.7286
# val epoch 49 : loss : 0.5445, acc: 0.7867, bma: 0.7634
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.2125, acc: 0.7520, bma: 0.7453
# val epoch 50 : loss : 0.5237, acc: 0.8133, bma: 0.8120
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.2201, acc: 0.7585, bma: 0.7545
# val epoch 51 : loss : 0.5888, acc: 0.7400, bma: 0.7681
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.2203, acc: 0.7467, bma: 0.7487
# val epoch 52 : loss : 0.5367, acc: 0.7667, bma: 0.7400
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.2043, acc: 0.7703, bma: 0.7674
# val epoch 53 : loss : 0.5461, acc: 0.8000, bma: 0.7956
#
# Epoch 54/100
# ----------
# train epoch 54 : loss : 0.2065, acc: 0.7717, bma: 0.7689
# val epoch 54 : loss : 0.5407, acc: 0.7733, bma: 0.7543
#
# Epoch 55/100
# ----------
# train epoch 55 : loss : 0.2163, acc: 0.7467, bma: 0.7478
# val epoch 55 : loss : 0.5525, acc: 0.7933, bma: 0.7987
#
# Epoch 56/100
# ----------
# train epoch 56 : loss : 0.2143, acc: 0.7677, bma: 0.7693
# val epoch 56 : loss : 0.5223, acc: 0.8067, bma: 0.7720
#
# Epoch 57/100
# ----------
# train epoch 57 : loss : 0.2022, acc: 0.7756, bma: 0.7722
# val epoch 57 : loss : 0.5241, acc: 0.8000, bma: 0.7751
#
# Epoch 58/100
# ----------
# train epoch 58 : loss : 0.2184, acc: 0.7651, bma: 0.7657
# val epoch 58 : loss : 0.5552, acc: 0.7600, bma: 0.7363
#
# Epoch 59/100
# ----------
# train epoch 59 : loss : 0.2230, acc: 0.7283, bma: 0.7311
# val epoch 59 : loss : 0.5425, acc: 0.7600, bma: 0.7253
#
# Epoch 60/100
# ----------
# train epoch 60 : loss : 0.1987, acc: 0.7887, bma: 0.7935
# val epoch 60 : loss : 0.5331, acc: 0.7867, bma: 0.7314
#
# Epoch 61/100
# ----------
# train epoch 61 : loss : 0.2076, acc: 0.7572, bma: 0.7573
# val epoch 61 : loss : 0.5464, acc: 0.7867, bma: 0.7602
#
# Epoch 62/100
# ----------
# train epoch 62 : loss : 0.1903, acc: 0.7966, bma: 0.7944
# val epoch 62 : loss : 0.5444, acc: 0.7933, bma: 0.7718
#
# Epoch 63/100
# ----------
# train epoch 63 : loss : 0.2065, acc: 0.7612, bma: 0.7624
# val epoch 63 : loss : 0.5349, acc: 0.8000, bma: 0.7719
#
# Epoch 64/100
# ----------
# train epoch 64 : loss : 0.1970, acc: 0.7835, bma: 0.7834
# val epoch 64 : loss : 0.5266, acc: 0.8000, bma: 0.7656
#
# Epoch 65/100
# ----------
# train epoch 65 : loss : 0.1963, acc: 0.7835, bma: 0.7824
# val epoch 65 : loss : 0.5032, acc: 0.8067, bma: 0.7752
#
# Epoch 66/100
# ----------
# train epoch 66 : loss : 0.2115, acc: 0.7651, bma: 0.7646
# val epoch 66 : loss : 0.5271, acc: 0.8267, bma: 0.8000
#
# Epoch 67/100
# ----------
# train epoch 67 : loss : 0.2110, acc: 0.7769, bma: 0.7730
# val epoch 67 : loss : 0.5077, acc: 0.8200, bma: 0.7989
#
# Epoch 68/100
# ----------
# train epoch 68 : loss : 0.2082, acc: 0.7625, bma: 0.7584
# val epoch 68 : loss : 0.5197, acc: 0.8333, bma: 0.8143
#
# Epoch 69/100
# ----------
# train epoch 69 : loss : 0.1942, acc: 0.7743, bma: 0.7795
# val epoch 69 : loss : 0.5016, acc: 0.8067, bma: 0.7835
#
# Epoch 70/100
# ----------
# train epoch 70 : loss : 0.1908, acc: 0.7835, bma: 0.7841
# val epoch 70 : loss : 0.5023, acc: 0.7733, bma: 0.7570
#
# Epoch 71/100
# ----------
# train epoch 71 : loss : 0.1992, acc: 0.7848, bma: 0.7931
# val epoch 71 : loss : 0.5138, acc: 0.8067, bma: 0.7799
#
# Epoch 72/100
# ----------
# train epoch 72 : loss : 0.1981, acc: 0.7730, bma: 0.7735
# val epoch 72 : loss : 0.4891, acc: 0.8067, bma: 0.7684
#
# Epoch 73/100
# ----------
# train epoch 73 : loss : 0.1973, acc: 0.7808, bma: 0.7775
# val epoch 73 : loss : 0.5479, acc: 0.8067, bma: 0.7904
#
# Epoch 74/100
# ----------
# train epoch 74 : loss : 0.1918, acc: 0.7900, bma: 0.7865
# val epoch 74 : loss : 0.4958, acc: 0.8133, bma: 0.7736
#
# Epoch 75/100
# ----------
# train epoch 75 : loss : 0.1876, acc: 0.7861, bma: 0.7862
# val epoch 75 : loss : 0.4919, acc: 0.8267, bma: 0.8095
#
# Epoch 76/100
# ----------
# train epoch 76 : loss : 0.1993, acc: 0.7743, bma: 0.7755
# val epoch 76 : loss : 0.4882, acc: 0.8133, bma: 0.7973
#
# Epoch 77/100
# ----------
# train epoch 77 : loss : 0.1851, acc: 0.7913, bma: 0.7892
# val epoch 77 : loss : 0.5144, acc: 0.8067, bma: 0.7894
#
# Epoch 78/100
# ----------
# train epoch 78 : loss : 0.1794, acc: 0.8058, bma: 0.8024
# val epoch 78 : loss : 0.5431, acc: 0.7933, bma: 0.8023
#
# Epoch 79/100
# ----------
# train epoch 79 : loss : 0.1871, acc: 0.8031, bma: 0.8054
# val epoch 79 : loss : 0.5199, acc: 0.8000, bma: 0.7783
#
# Epoch 80/100
# ----------
# train epoch 80 : loss : 0.1902, acc: 0.7756, bma: 0.7740
# val epoch 80 : loss : 0.5658, acc: 0.7867, bma: 0.7844
#
# Epoch 81/100
# ----------
# train epoch 81 : loss : 0.1970, acc: 0.7743, bma: 0.7765
# val epoch 81 : loss : 0.5359, acc: 0.8000, bma: 0.8029
#
# Epoch 82/100
# ----------
# train epoch 82 : loss : 0.2056, acc: 0.7598, bma: 0.7599
# val epoch 82 : loss : 0.5443, acc: 0.7933, bma: 0.7918
#
# Epoch 83/100
# ----------
# train epoch 83 : loss : 0.1850, acc: 0.8058, bma: 0.8081
# val epoch 83 : loss : 0.5830, acc: 0.7667, bma: 0.7716
#
# Epoch 84/100
# ----------
# train epoch 84 : loss : 0.1723, acc: 0.8189, bma: 0.8180
# val epoch 84 : loss : 0.5264, acc: 0.8000, bma: 0.7893
#
# Epoch 85/100
# ----------
# train epoch 85 : loss : 0.1883, acc: 0.8005, bma: 0.8031
# val epoch 85 : loss : 0.5087, acc: 0.8067, bma: 0.8040
#
# Epoch 86/100
# ----------
# train epoch 86 : loss : 0.1710, acc: 0.8241, bma: 0.8247
# val epoch 86 : loss : 0.5250, acc: 0.8000, bma: 0.7961
#
# Epoch 87/100
# ----------
# train epoch 87 : loss : 0.1859, acc: 0.7953, bma: 0.7948
# val epoch 87 : loss : 0.5221, acc: 0.8200, bma: 0.8094
#
# Epoch 88/100
# ----------
# train epoch 88 : loss : 0.1845, acc: 0.8031, bma: 0.8013
# val epoch 88 : loss : 0.5183, acc: 0.7933, bma: 0.7813
#
# Epoch 89/100
# ----------
# train epoch 89 : loss : 0.1667, acc: 0.8228, bma: 0.8238
# val epoch 89 : loss : 0.5531, acc: 0.7733, bma: 0.7621
#
# Epoch 90/100
# ----------
# train epoch 90 : loss : 0.1763, acc: 0.8058, bma: 0.8044
# val epoch 90 : loss : 0.5082, acc: 0.8200, bma: 0.8126
#
# Epoch 91/100
# ----------
# train epoch 91 : loss : 0.1697, acc: 0.8150, bma: 0.8113
# val epoch 91 : loss : 0.5018, acc: 0.8267, bma: 0.8132
#
# Epoch 92/100
# ----------
# train epoch 92 : loss : 0.1688, acc: 0.8097, bma: 0.8122
# val epoch 92 : loss : 0.5358, acc: 0.8133, bma: 0.8120
# EARLY STOP AFTER 92 EPOCHS
# Training complete in 230m 14s
# Best val loss: 0.488212
# Best val BMA: 0.8142857142857144

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(densenet, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.6613 Acc: 0.7167, BMA: 0.7138
# Testing complete in 7m 54s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.6613, acc: 0.7167, bma: 0.7138

# %% [markdown]
# Show some results

# %%
visualize_model(densenet, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/densenest_ce_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 7
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
densenet = make_densenet(True)

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(densenet.parameters(), lr = LR, weight_decay=WD)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model:Densenet, LR: 1e-4, LR patience = 7, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8, with sampling')
# Out:
# Model:Densenet, LR: 1e-4, LR patience = 7, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8, with sampling

# %%
densenet = train_model(densenet, dataloaders_balanced, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.3273, acc: 0.6089, bma: 0.6092
# val epoch 1 : loss : 0.7826, acc: 0.6400, bma: 0.6821
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.2808, acc: 0.6693, bma: 0.6689
# val epoch 2 : loss : 0.6607, acc: 0.7267, bma: 0.6976
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.2866, acc: 0.6877, bma: 0.6836
# val epoch 3 : loss : 0.7664, acc: 0.6533, bma: 0.6017
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.2576, acc: 0.7021, bma: 0.7021
# val epoch 4 : loss : 0.5749, acc: 0.7533, bma: 0.6726
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.2556, acc: 0.6942, bma: 0.6975
# val epoch 5 : loss : 0.6332, acc: 0.7600, bma: 0.6811
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.2430, acc: 0.7100, bma: 0.7113
# val epoch 6 : loss : 0.6567, acc: 0.6733, bma: 0.6570
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.2493, acc: 0.7100, bma: 0.7129
# val epoch 7 : loss : 0.5323, acc: 0.7533, bma: 0.7247
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.2307, acc: 0.7415, bma: 0.7379
# val epoch 8 : loss : 0.6851, acc: 0.7133, bma: 0.7000
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.2011, acc: 0.7638, bma: 0.7651
# val epoch 9 : loss : 0.5985, acc: 0.7467, bma: 0.7646
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.2276, acc: 0.7441, bma: 0.7430
# val epoch 10 : loss : 0.5390, acc: 0.7400, bma: 0.6783
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.2148, acc: 0.7585, bma: 0.7599
# val epoch 11 : loss : 0.5875, acc: 0.7600, bma: 0.7531
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.2235, acc: 0.7585, bma: 0.7571
# val epoch 12 : loss : 0.6642, acc: 0.6933, bma: 0.6926
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.1946, acc: 0.7795, bma: 0.7815
# val epoch 13 : loss : 0.6808, acc: 0.6933, bma: 0.6689
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.2003, acc: 0.7808, bma: 0.7751
# val epoch 14 : loss : 0.6138, acc: 0.7400, bma: 0.7120
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.1965, acc: 0.7835, bma: 0.7845
# val epoch 15 : loss : 0.5281, acc: 0.7733, bma: 0.7643
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.1819, acc: 0.7913, bma: 0.7870
# val epoch 16 : loss : 0.5191, acc: 0.7333, bma: 0.6803
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.1917, acc: 0.7927, bma: 0.7918
# val epoch 17 : loss : 0.5262, acc: 0.7600, bma: 0.7695
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.1743, acc: 0.8031, bma: 0.7977
# val epoch 18 : loss : 0.5023, acc: 0.8133, bma: 0.7841
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.1774, acc: 0.8110, bma: 0.8118
# val epoch 19 : loss : 0.5493, acc: 0.7400, bma: 0.7024
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.1685, acc: 0.8255, bma: 0.8273
# val epoch 20 : loss : 0.5291, acc: 0.7467, bma: 0.7245
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.1660, acc: 0.8189, bma: 0.8115
# val epoch 21 : loss : 0.5827, acc: 0.7133, bma: 0.7085
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.1621, acc: 0.8150, bma: 0.8168
# val epoch 22 : loss : 0.5636, acc: 0.7467, bma: 0.7578
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.1710, acc: 0.8150, bma: 0.8131
# val epoch 23 : loss : 0.5158, acc: 0.7533, bma: 0.7515
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.1733, acc: 0.8215, bma: 0.8254
# val epoch 24 : loss : 0.5751, acc: 0.7800, bma: 0.7833
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.1487, acc: 0.8478, bma: 0.8435
# val epoch 25 : loss : 0.6390, acc: 0.7467, bma: 0.7140
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.1620, acc: 0.8307, bma: 0.8328
# val epoch 26 : loss : 0.5036, acc: 0.7933, bma: 0.8087
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.1505, acc: 0.8294, bma: 0.8356
# val epoch 27 : loss : 0.4518, acc: 0.8067, bma: 0.7725
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.1514, acc: 0.8268, bma: 0.8233
# val epoch 28 : loss : 0.4438, acc: 0.7667, bma: 0.7269
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.1519, acc: 0.8425, bma: 0.8434
# val epoch 29 : loss : 0.4650, acc: 0.7867, bma: 0.7834
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.1257, acc: 0.8622, bma: 0.8610
# val epoch 30 : loss : 0.4415, acc: 0.7933, bma: 0.7540
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.1350, acc: 0.8727, bma: 0.8750
# val epoch 31 : loss : 0.5127, acc: 0.8000, bma: 0.7624
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.1284, acc: 0.8635, bma: 0.8663
# val epoch 32 : loss : 0.4599, acc: 0.8133, bma: 0.7873
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.1278, acc: 0.8609, bma: 0.8612
# val epoch 33 : loss : 0.5000, acc: 0.7800, bma: 0.7659
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.1208, acc: 0.8819, bma: 0.8818
# val epoch 34 : loss : 0.4270, acc: 0.8067, bma: 0.7899
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.1259, acc: 0.8583, bma: 0.8568
# val epoch 35 : loss : 0.4706, acc: 0.7867, bma: 0.7429
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.1138, acc: 0.8832, bma: 0.8844
# val epoch 36 : loss : 0.4372, acc: 0.7867, bma: 0.7834
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.1124, acc: 0.8871, bma: 0.8869
# val epoch 37 : loss : 0.4613, acc: 0.8067, bma: 0.7799
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.1208, acc: 0.8635, bma: 0.8620
# val epoch 38 : loss : 0.4548, acc: 0.8067, bma: 0.7657
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.1160, acc: 0.8950, bma: 0.8934
# val epoch 39 : loss : 0.4817, acc: 0.8200, bma: 0.8231
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.1232, acc: 0.8714, bma: 0.8695
# val epoch 40 : loss : 0.4150, acc: 0.8533, bma: 0.8166
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.1114, acc: 0.8885, bma: 0.8899
# val epoch 41 : loss : 0.4069, acc: 0.8200, bma: 0.8153
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.1168, acc: 0.8766, bma: 0.8740
# val epoch 42 : loss : 0.4911, acc: 0.7867, bma: 0.7433
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.1019, acc: 0.9121, bma: 0.9111
# val epoch 43 : loss : 0.4250, acc: 0.8133, bma: 0.8115
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.1099, acc: 0.8858, bma: 0.8836
# val epoch 44 : loss : 0.4245, acc: 0.8267, bma: 0.8127
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.1007, acc: 0.8871, bma: 0.8879
# val epoch 45 : loss : 0.3995, acc: 0.8000, bma: 0.7619
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.1023, acc: 0.9055, bma: 0.9058
# val epoch 46 : loss : 0.4838, acc: 0.8000, bma: 0.7346
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.1176, acc: 0.8701, bma: 0.8683
# val epoch 47 : loss : 0.3787, acc: 0.8333, bma: 0.7938
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.0912, acc: 0.9213, bma: 0.9228
# val epoch 48 : loss : 0.5672, acc: 0.7600, bma: 0.7089
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.0935, acc: 0.9055, bma: 0.9068
# val epoch 49 : loss : 0.4368, acc: 0.8133, bma: 0.8015
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.0898, acc: 0.9134, bma: 0.9140
# val epoch 50 : loss : 0.5210, acc: 0.7667, bma: 0.7564
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.0949, acc: 0.9094, bma: 0.9094
# val epoch 51 : loss : 0.4690, acc: 0.8200, bma: 0.8057
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.0974, acc: 0.8976, bma: 0.8972
# val epoch 52 : loss : 0.4268, acc: 0.8400, bma: 0.8117
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.0952, acc: 0.9108, bma: 0.9103
# val epoch 53 : loss : 0.4917, acc: 0.8067, bma: 0.7730
#
# Epoch 54/100
# ----------
# train epoch 54 : loss : 0.0957, acc: 0.9003, bma: 0.9005
# val epoch 54 : loss : 0.4680, acc: 0.8400, bma: 0.8149
#
# Epoch 55/100
# ----------
# train epoch 55 : loss : 0.0861, acc: 0.9213, bma: 0.9207
# val epoch 55 : loss : 0.4775, acc: 0.8000, bma: 0.7546
#
# Epoch 56/100
# ----------
# train epoch 56 : loss : 0.0790, acc: 0.9265, bma: 0.9274
# val epoch 56 : loss : 0.4619, acc: 0.8067, bma: 0.7557
#
# Epoch 57/100
# ----------
# train epoch 57 : loss : 0.0857, acc: 0.9213, bma: 0.9186
# val epoch 57 : loss : 0.4991, acc: 0.8200, bma: 0.7847
#
# Epoch 58/100
# ----------
# train epoch 58 : loss : 0.0747, acc: 0.9265, bma: 0.9266
# val epoch 58 : loss : 0.4480, acc: 0.8067, bma: 0.7730
# EARLY STOP AFTER 58 EPOCHS
# Training complete in 139m 8s
# Best val loss: 0.378702
# Best val BMA: 0.8230769230769232

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(densenet, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.6837 Acc: 0.7567, BMA: 0.7527
# Testing complete in 3m 26s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.6837, acc: 0.7567, bma: 0.7527

# %% [markdown]
# Show some results

# %%
visualize_model(densenet, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %% [markdown]
# ## 2. Vision Transformer

# %% [markdown]
# #### With Focal Loss

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/Densenet/vit_fl_sgd.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
vit  = make_vitb16(True)

criterion = FocalLoss(alpha = class_weights, gamma = 2.0, size_average= True)

optimizer = optim.SGD(vit.parameters(), lr = LR, weight_decay=WD, momentum = 0.9)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.1, mode="min")

# %%
logging.info('Model: VIT, Base LR: 1e-4, LR patience = 5, loss: Focal, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9')
# Out:
# Model: VIT, Base LR: 1e-4, LR patience = 5, loss: Focal, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9

# %%
vit = train_model(vit, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.4493, acc: 0.4325, bma: 0.4686
# val epoch 1 : loss : 0.6122, acc: 0.4667, bma: 0.4786
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.3597, acc: 0.5755, bma: 0.5977
# val epoch 2 : loss : 0.5246, acc: 0.5733, bma: 0.5731
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.3207, acc: 0.6075, bma: 0.6498
# val epoch 3 : loss : 0.4761, acc: 0.6333, bma: 0.6162
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.2976, acc: 0.6160, bma: 0.6603
# val epoch 4 : loss : 0.4614, acc: 0.6600, bma: 0.6360
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.2812, acc: 0.6400, bma: 0.6766
# val epoch 5 : loss : 0.4039, acc: 0.6333, bma: 0.6477
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.2697, acc: 0.6475, bma: 0.7002
# val epoch 6 : loss : 0.4117, acc: 0.6333, bma: 0.6067
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.2629, acc: 0.6605, bma: 0.7050
# val epoch 7 : loss : 0.4039, acc: 0.6533, bma: 0.6391
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.2476, acc: 0.6790, bma: 0.7176
# val epoch 8 : loss : 0.3958, acc: 0.6467, bma: 0.6516
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.2437, acc: 0.6800, bma: 0.7188
# val epoch 9 : loss : 0.3921, acc: 0.6400, bma: 0.6400
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.2322, acc: 0.6770, bma: 0.7225
# val epoch 10 : loss : 0.3771, acc: 0.6733, bma: 0.6692
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.2335, acc: 0.6885, bma: 0.7345
# val epoch 11 : loss : 0.3743, acc: 0.6800, bma: 0.6667
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.2244, acc: 0.6920, bma: 0.7222
# val epoch 12 : loss : 0.3569, acc: 0.6733, bma: 0.6724
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.2162, acc: 0.7140, bma: 0.7460
# val epoch 13 : loss : 0.3593, acc: 0.7000, bma: 0.6995
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.2106, acc: 0.7205, bma: 0.7600
# val epoch 14 : loss : 0.3495, acc: 0.7000, bma: 0.6868
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.2031, acc: 0.7245, bma: 0.7565
# val epoch 15 : loss : 0.3499, acc: 0.6800, bma: 0.6767
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.1989, acc: 0.7180, bma: 0.7633
# val epoch 16 : loss : 0.3414, acc: 0.6533, bma: 0.6432
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.1935, acc: 0.7290, bma: 0.7652
# val epoch 17 : loss : 0.3524, acc: 0.6533, bma: 0.6332
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.1957, acc: 0.7315, bma: 0.7662
# val epoch 18 : loss : 0.3331, acc: 0.6800, bma: 0.7009
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.1846, acc: 0.7505, bma: 0.7842
# val epoch 19 : loss : 0.3519, acc: 0.7133, bma: 0.7049
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.1807, acc: 0.7500, bma: 0.7926
# val epoch 20 : loss : 0.3529, acc: 0.7267, bma: 0.7002
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.1807, acc: 0.7460, bma: 0.7769
# val epoch 21 : loss : 0.3232, acc: 0.7133, bma: 0.7117
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.1750, acc: 0.7530, bma: 0.7938
# val epoch 22 : loss : 0.3380, acc: 0.7133, bma: 0.7081
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.1643, acc: 0.7765, bma: 0.8145
# val epoch 23 : loss : 0.3298, acc: 0.7200, bma: 0.7123
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.1631, acc: 0.7530, bma: 0.7848
# val epoch 24 : loss : 0.3175, acc: 0.7267, bma: 0.7139
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.1634, acc: 0.7615, bma: 0.7941
# val epoch 25 : loss : 0.3475, acc: 0.7200, bma: 0.7123
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.1676, acc: 0.7635, bma: 0.8015
# val epoch 26 : loss : 0.3252, acc: 0.7133, bma: 0.6949
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.1517, acc: 0.7760, bma: 0.8095
# val epoch 27 : loss : 0.3212, acc: 0.7133, bma: 0.7085
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.1544, acc: 0.7700, bma: 0.8019
# val epoch 28 : loss : 0.3304, acc: 0.7000, bma: 0.6900
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.1477, acc: 0.7840, bma: 0.8224
# val epoch 29 : loss : 0.3321, acc: 0.7000, bma: 0.6827
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.1480, acc: 0.7775, bma: 0.8092
# val epoch 30 : loss : 0.3092, acc: 0.7267, bma: 0.7139
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.1347, acc: 0.8000, bma: 0.8358
# val epoch 31 : loss : 0.3069, acc: 0.6933, bma: 0.6957
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.1480, acc: 0.7685, bma: 0.8035
# val epoch 32 : loss : 0.3200, acc: 0.7067, bma: 0.6869
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.1300, acc: 0.8060, bma: 0.8363
# val epoch 33 : loss : 0.3494, acc: 0.7467, bma: 0.7326
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.1316, acc: 0.7945, bma: 0.8353
# val epoch 34 : loss : 0.3365, acc: 0.7200, bma: 0.6955
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.1279, acc: 0.7980, bma: 0.8363
# val epoch 35 : loss : 0.3021, acc: 0.7400, bma: 0.7256
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.1289, acc: 0.7945, bma: 0.8290
# val epoch 36 : loss : 0.3040, acc: 0.7400, bma: 0.7293
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.1331, acc: 0.7995, bma: 0.8388
# val epoch 37 : loss : 0.2982, acc: 0.7400, bma: 0.7293
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.1301, acc: 0.7965, bma: 0.8377
# val epoch 38 : loss : 0.3141, acc: 0.7467, bma: 0.7267
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.1230, acc: 0.8055, bma: 0.8363
# val epoch 39 : loss : 0.3077, acc: 0.7333, bma: 0.7145
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.1200, acc: 0.8160, bma: 0.8537
# val epoch 40 : loss : 0.3598, acc: 0.7600, bma: 0.6979
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.1271, acc: 0.8050, bma: 0.8434
# val epoch 41 : loss : 0.3454, acc: 0.7333, bma: 0.7045
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.1257, acc: 0.8045, bma: 0.8281
# val epoch 42 : loss : 0.2954, acc: 0.7400, bma: 0.7193
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.1185, acc: 0.8070, bma: 0.8454
# val epoch 43 : loss : 0.3443, acc: 0.7000, bma: 0.6863
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.1151, acc: 0.8130, bma: 0.8449
# val epoch 44 : loss : 0.3093, acc: 0.7400, bma: 0.7188
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.1143, acc: 0.8185, bma: 0.8478
# val epoch 45 : loss : 0.3148, acc: 0.6933, bma: 0.7026
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.1080, acc: 0.8120, bma: 0.8491
# val epoch 46 : loss : 0.3322, acc: 0.7467, bma: 0.7062
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.1147, acc: 0.8215, bma: 0.8529
# val epoch 47 : loss : 0.3541, acc: 0.7267, bma: 0.6861
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.1088, acc: 0.8225, bma: 0.8540
# val epoch 48 : loss : 0.3043, acc: 0.7533, bma: 0.7173
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.1011, acc: 0.8430, bma: 0.8761
# val epoch 49 : loss : 0.3048, acc: 0.7533, bma: 0.7205
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.1033, acc: 0.8375, bma: 0.8639
# val epoch 50 : loss : 0.3030, acc: 0.7467, bma: 0.7194
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.0998, acc: 0.8370, bma: 0.8676
# val epoch 51 : loss : 0.2993, acc: 0.7600, bma: 0.7316
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.0954, acc: 0.8340, bma: 0.8700
# val epoch 52 : loss : 0.3116, acc: 0.7533, bma: 0.7237
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.0960, acc: 0.8475, bma: 0.8791
# val epoch 53 : loss : 0.3091, acc: 0.7600, bma: 0.7316
# EARLY STOP AFTER 53 EPOCHS
# Training complete in 258m 37s
# Best val loss: 0.295434
# Best val BMA: 0.7326007326007327

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(vit, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.3217 Acc: 0.6667, BMA: 0.6729
# Testing complete in 3m 26s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.3217, acc: 0.6667, bma: 0.6729

# %% [markdown]
# Show some results

# %%
visualize_model(vit, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 1
# Actual: 0, predicted: 1
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %%
torch.save(vit.state_dict(), '/content/drive/MyDrive/MRTYUTeam/classification_checkpoints/vit_fl_sgd.pth')

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT/vit_fl_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT'

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
vit  = make_vitb16(True)

criterion = FocalLoss(alpha = class_weights, gamma = 2.0, size_average= True)

optimizer =  optim.Adam(vit.parameters(), lr = LR, weight_decay=WD)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model:VIT, LR: 1e-4, LR patience = 5, loss: Focal, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8')
# Out:
# Model:VIT, LR: 1e-4, LR patience = 5, loss: Focal, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8

# %%
vit = train_model(vit, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.5068, acc: 0.3955, bma: 0.4203
# val epoch 1 : loss : 0.6895, acc: 0.6000, bma: 0.5863
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.4535, acc: 0.4310, bma: 0.4519
# val epoch 2 : loss : 0.5472, acc: 0.5400, bma: 0.4849
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.4314, acc: 0.4745, bma: 0.4976
# val epoch 3 : loss : 0.4808, acc: 0.3733, bma: 0.3932
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.4441, acc: 0.4500, bma: 0.4824
# val epoch 4 : loss : 0.6007, acc: 0.6000, bma: 0.5392
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.4182, acc: 0.4575, bma: 0.5061
# val epoch 5 : loss : 0.4920, acc: 0.4600, bma: 0.5256
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.4044, acc: 0.4990, bma: 0.5426
# val epoch 6 : loss : 0.4524, acc: 0.5267, bma: 0.5689
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.4038, acc: 0.4615, bma: 0.5100
# val epoch 7 : loss : 0.5816, acc: 0.6133, bma: 0.6183
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.3860, acc: 0.5145, bma: 0.5610
# val epoch 8 : loss : 0.4577, acc: 0.4867, bma: 0.5486
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.3958, acc: 0.4855, bma: 0.5422
# val epoch 9 : loss : 0.5001, acc: 0.5867, bma: 0.5885
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.3815, acc: 0.5270, bma: 0.5616
# val epoch 10 : loss : 0.4501, acc: 0.5467, bma: 0.5297
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.3726, acc: 0.5220, bma: 0.5689
# val epoch 11 : loss : 0.4715, acc: 0.6200, bma: 0.5713
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.3750, acc: 0.5305, bma: 0.5651
# val epoch 12 : loss : 0.4762, acc: 0.5200, bma: 0.5477
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.3792, acc: 0.5290, bma: 0.5741
# val epoch 13 : loss : 0.5711, acc: 0.4133, bma: 0.4694
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.3895, acc: 0.5390, bma: 0.5699
# val epoch 14 : loss : 0.4631, acc: 0.5267, bma: 0.5442
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.3616, acc: 0.5365, bma: 0.5752
# val epoch 15 : loss : 0.4549, acc: 0.5400, bma: 0.5259
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.3622, acc: 0.5540, bma: 0.5946
# val epoch 16 : loss : 0.4727, acc: 0.5867, bma: 0.6432
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.3268, acc: 0.5865, bma: 0.6356
# val epoch 17 : loss : 0.3959, acc: 0.6200, bma: 0.6118
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.3218, acc: 0.5985, bma: 0.6335
# val epoch 18 : loss : 0.4401, acc: 0.6200, bma: 0.6267
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.3091, acc: 0.6060, bma: 0.6365
# val epoch 19 : loss : 0.3933, acc: 0.6267, bma: 0.6056
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.3142, acc: 0.6105, bma: 0.6486
# val epoch 20 : loss : 0.4429, acc: 0.5933, bma: 0.5860
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.3097, acc: 0.6040, bma: 0.6401
# val epoch 21 : loss : 0.4585, acc: 0.5400, bma: 0.5581
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.2912, acc: 0.6065, bma: 0.6458
# val epoch 22 : loss : 0.5803, acc: 0.6267, bma: 0.5607
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.3011, acc: 0.5945, bma: 0.6282
# val epoch 23 : loss : 0.4103, acc: 0.6400, bma: 0.6068
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.3062, acc: 0.6065, bma: 0.6465
# val epoch 24 : loss : 0.4342, acc: 0.6400, bma: 0.5832
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.2801, acc: 0.6250, bma: 0.6602
# val epoch 25 : loss : 0.5016, acc: 0.6067, bma: 0.6231
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.2640, acc: 0.6510, bma: 0.6791
# val epoch 26 : loss : 0.4232, acc: 0.6400, bma: 0.6005
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.2551, acc: 0.6535, bma: 0.6872
# val epoch 27 : loss : 0.3680, acc: 0.6067, bma: 0.6165
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.2587, acc: 0.6540, bma: 0.6898
# val epoch 28 : loss : 0.3928, acc: 0.6667, bma: 0.6244
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.2481, acc: 0.6645, bma: 0.7020
# val epoch 29 : loss : 0.4292, acc: 0.6533, bma: 0.6527
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.2472, acc: 0.6760, bma: 0.7104
# val epoch 30 : loss : 0.3747, acc: 0.6533, bma: 0.6400
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.2490, acc: 0.6860, bma: 0.7069
# val epoch 31 : loss : 0.3475, acc: 0.6667, bma: 0.6691
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.2427, acc: 0.6745, bma: 0.7032
# val epoch 32 : loss : 0.3311, acc: 0.6400, bma: 0.6283
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.2241, acc: 0.6890, bma: 0.7221
# val epoch 33 : loss : 0.3890, acc: 0.6133, bma: 0.5907
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.2309, acc: 0.6960, bma: 0.7332
# val epoch 34 : loss : 0.3628, acc: 0.6600, bma: 0.6123
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.2167, acc: 0.6955, bma: 0.7349
# val epoch 35 : loss : 0.4401, acc: 0.6533, bma: 0.6481
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.2173, acc: 0.7085, bma: 0.7414
# val epoch 36 : loss : 0.4237, acc: 0.6333, bma: 0.5984
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.2145, acc: 0.7000, bma: 0.7376
# val epoch 37 : loss : 0.3500, acc: 0.6400, bma: 0.5868
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.2010, acc: 0.7240, bma: 0.7554
# val epoch 38 : loss : 0.4448, acc: 0.6600, bma: 0.6087
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.2070, acc: 0.7075, bma: 0.7442
# val epoch 39 : loss : 0.3744, acc: 0.6400, bma: 0.6305
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.1885, acc: 0.7250, bma: 0.7557
# val epoch 40 : loss : 0.3296, acc: 0.6867, bma: 0.6372
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.2038, acc: 0.7080, bma: 0.7427
# val epoch 41 : loss : 0.3285, acc: 0.6600, bma: 0.6470
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.1850, acc: 0.7280, bma: 0.7513
# val epoch 42 : loss : 0.3337, acc: 0.6667, bma: 0.6481
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.1644, acc: 0.7565, bma: 0.7974
# val epoch 43 : loss : 0.3477, acc: 0.6933, bma: 0.6652
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.1926, acc: 0.7345, bma: 0.7625
# val epoch 44 : loss : 0.3213, acc: 0.6733, bma: 0.6260
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.1784, acc: 0.7435, bma: 0.7755
# val epoch 45 : loss : 0.3225, acc: 0.6733, bma: 0.6634
#
# Epoch 46/100
# ----------
# train epoch 46 : loss : 0.1708, acc: 0.7505, bma: 0.7848
# val epoch 46 : loss : 0.3612, acc: 0.7067, bma: 0.6706
#
# Epoch 47/100
# ----------
# train epoch 47 : loss : 0.1537, acc: 0.7655, bma: 0.7962
# val epoch 47 : loss : 0.3992, acc: 0.6533, bma: 0.6164
#
# Epoch 48/100
# ----------
# train epoch 48 : loss : 0.1772, acc: 0.7490, bma: 0.7811
# val epoch 48 : loss : 0.3568, acc: 0.6800, bma: 0.6593
#
# Epoch 49/100
# ----------
# train epoch 49 : loss : 0.1562, acc: 0.7580, bma: 0.7922
# val epoch 49 : loss : 0.3844, acc: 0.7067, bma: 0.6943
#
# Epoch 50/100
# ----------
# train epoch 50 : loss : 0.1524, acc: 0.7655, bma: 0.8024
# val epoch 50 : loss : 0.4089, acc: 0.6800, bma: 0.6730
#
# Epoch 51/100
# ----------
# train epoch 51 : loss : 0.1594, acc: 0.7630, bma: 0.7989
# val epoch 51 : loss : 0.4019, acc: 0.7200, bma: 0.6896
#
# Epoch 52/100
# ----------
# train epoch 52 : loss : 0.1373, acc: 0.7790, bma: 0.8151
# val epoch 52 : loss : 0.4067, acc: 0.7133, bma: 0.6785
#
# Epoch 53/100
# ----------
# train epoch 53 : loss : 0.1329, acc: 0.7845, bma: 0.8257
# val epoch 53 : loss : 0.4078, acc: 0.7067, bma: 0.6706
#
# Epoch 54/100
# ----------
# train epoch 54 : loss : 0.1449, acc: 0.7715, bma: 0.7998
# val epoch 54 : loss : 0.4470, acc: 0.6933, bma: 0.6589
#
# Epoch 55/100
# ----------
# train epoch 55 : loss : 0.1359, acc: 0.7895, bma: 0.8204
# val epoch 55 : loss : 0.3915, acc: 0.7333, bma: 0.7114
# EARLY STOP AFTER 55 EPOCHS
# Training complete in 272m 41s
# Best val loss: 0.321289
# Best val BMA: 0.7113553113553114

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(vit, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.4889 Acc: 0.6267, BMA: 0.6554
# Testing complete in 3m 28s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.4889, acc: 0.6267, bma: 0.6554

# %% [markdown]
# Show some results

# %%
visualize_model(vit, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 1
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 2
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2

# %% [markdown]
# #### With Weighted Cross Entropy

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT/vit_wce_sgd.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
vit = make_vitb16(True)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.SGD(vit.parameters(), lr = LR, weight_decay=WD, momentum = 0.9)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.1, mode="min")

# %%
logging.info('Model: ViT, LR init: 1e-4, LR patience = 5, loss: WCE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9')
# Out:
# Model: ViT, LR init: 1e-4, LR patience = 5, loss: WCE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9

# %%
vit = train_model(vit, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 1.0170, acc: 0.5190, bma: 0.4669
# val epoch 1 : loss : 0.9795, acc: 0.5800, bma: 0.5103
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.8600, acc: 0.6215, bma: 0.6151
# val epoch 2 : loss : 0.7985, acc: 0.6800, bma: 0.6415
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.7842, acc: 0.6525, bma: 0.6549
# val epoch 3 : loss : 0.7636, acc: 0.7000, bma: 0.6521
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.7481, acc: 0.6710, bma: 0.6686
# val epoch 4 : loss : 0.6945, acc: 0.6600, bma: 0.6370
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.7167, acc: 0.6915, bma: 0.6993
# val epoch 5 : loss : 0.7173, acc: 0.6933, bma: 0.6474
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.7159, acc: 0.6770, bma: 0.6875
# val epoch 6 : loss : 0.6775, acc: 0.7067, bma: 0.6706
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.7025, acc: 0.6850, bma: 0.6939
# val epoch 7 : loss : 0.6421, acc: 0.6933, bma: 0.6762
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.7299, acc: 0.6670, bma: 0.6759
# val epoch 8 : loss : 0.6089, acc: 0.7000, bma: 0.6426
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.6798, acc: 0.6930, bma: 0.7036
# val epoch 9 : loss : 0.6553, acc: 0.7400, bma: 0.6714
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.6451, acc: 0.7000, bma: 0.7116
# val epoch 10 : loss : 0.6166, acc: 0.7133, bma: 0.6858
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.6206, acc: 0.7240, bma: 0.7283
# val epoch 11 : loss : 0.6128, acc: 0.6800, bma: 0.6681
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.6183, acc: 0.7235, bma: 0.7384
# val epoch 12 : loss : 0.5669, acc: 0.7267, bma: 0.7071
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.6117, acc: 0.7240, bma: 0.7393
# val epoch 13 : loss : 0.5923, acc: 0.7267, bma: 0.7049
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.5860, acc: 0.7365, bma: 0.7476
# val epoch 14 : loss : 0.5562, acc: 0.7333, bma: 0.7260
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.5818, acc: 0.7390, bma: 0.7494
# val epoch 15 : loss : 0.6736, acc: 0.7133, bma: 0.6580
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.5762, acc: 0.7430, bma: 0.7573
# val epoch 16 : loss : 0.6717, acc: 0.7400, bma: 0.6741
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.5660, acc: 0.7390, bma: 0.7494
# val epoch 17 : loss : 0.5894, acc: 0.7400, bma: 0.7125
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.5651, acc: 0.7450, bma: 0.7510
# val epoch 18 : loss : 0.5749, acc: 0.7467, bma: 0.7158
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.5578, acc: 0.7545, bma: 0.7629
# val epoch 19 : loss : 0.5766, acc: 0.6800, bma: 0.6608
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.5394, acc: 0.7480, bma: 0.7675
# val epoch 20 : loss : 0.6559, acc: 0.7333, bma: 0.7072
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.5219, acc: 0.7800, bma: 0.7869
# val epoch 21 : loss : 0.5652, acc: 0.7400, bma: 0.7151
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.4657, acc: 0.8010, bma: 0.8152
# val epoch 22 : loss : 0.5435, acc: 0.7600, bma: 0.7389
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.4670, acc: 0.7895, bma: 0.8022
# val epoch 23 : loss : 0.5366, acc: 0.7400, bma: 0.7120
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.4675, acc: 0.7905, bma: 0.7970
# val epoch 24 : loss : 0.5420, acc: 0.7533, bma: 0.7210
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.4520, acc: 0.7885, bma: 0.8076
# val epoch 25 : loss : 0.5461, acc: 0.7467, bma: 0.7099
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.4528, acc: 0.8055, bma: 0.8186
# val epoch 26 : loss : 0.5313, acc: 0.7467, bma: 0.7199
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.4633, acc: 0.7950, bma: 0.8091
# val epoch 27 : loss : 0.5435, acc: 0.7533, bma: 0.7242
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.4452, acc: 0.7930, bma: 0.8102
# val epoch 28 : loss : 0.5321, acc: 0.7400, bma: 0.7093
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.4475, acc: 0.8000, bma: 0.8095
# val epoch 29 : loss : 0.5498, acc: 0.7333, bma: 0.7009
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.4593, acc: 0.8055, bma: 0.8154
# val epoch 30 : loss : 0.5406, acc: 0.7333, bma: 0.7045
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.4329, acc: 0.8110, bma: 0.8287
# val epoch 31 : loss : 0.5653, acc: 0.7333, bma: 0.7013
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.4439, acc: 0.8030, bma: 0.8190
# val epoch 32 : loss : 0.5461, acc: 0.7467, bma: 0.7136
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.4303, acc: 0.8190, bma: 0.8383
# val epoch 33 : loss : 0.5461, acc: 0.7467, bma: 0.7136
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.4288, acc: 0.8115, bma: 0.8175
# val epoch 34 : loss : 0.5427, acc: 0.7400, bma: 0.7093
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.4312, acc: 0.8115, bma: 0.8177
# val epoch 35 : loss : 0.5427, acc: 0.7400, bma: 0.7093
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.4331, acc: 0.8040, bma: 0.8227
# val epoch 36 : loss : 0.5427, acc: 0.7333, bma: 0.7050
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.4133, acc: 0.8165, bma: 0.8363
# val epoch 37 : loss : 0.5432, acc: 0.7333, bma: 0.7050
# EARLY STOP AFTER 37 EPOCHS
# Training complete in 180m 20s
# Best val loss: 0.531336
# Best val BMA: 0.738949938949939

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(vit, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.7611 Acc: 0.6383, BMA: 0.6802
# Testing complete in 3m 24s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.7611, acc: 0.6383, bma: 0.6802

# %% [markdown]
# Show some results

# %%
visualize_model(vit, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 1
# Actual: 0, predicted: 1
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 0
# Actual: 2, predicted: 1

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT/vit_wce_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/MRTYUTeam/Tensorboard/Classification/VIT'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 10
ES_PATIENCE = 15

EPOCHS = 100
WD = 0

# %%
vit =  make_vitb16(True)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(vit.parameters(), lr = LR, weight_decay=WD)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model: Vit, LR: 1e-4, LR patience = 10, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 0')

# %%
vit = train_model(vit, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.9170, acc: 0.5705, bma: 0.5469
# val epoch 1 : loss : 0.7523, acc: 0.6600, bma: 0.6060
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.7318, acc: 0.6700, bma: 0.6847
# val epoch 2 : loss : 0.6291, acc: 0.6867, bma: 0.7051
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.6878, acc: 0.6940, bma: 0.7028
# val epoch 3 : loss : 0.5933, acc: 0.7267, bma: 0.7249
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.6145, acc: 0.7150, bma: 0.7358
# val epoch 4 : loss : 0.6721, acc: 0.7000, bma: 0.6399
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.5688, acc: 0.7495, bma: 0.7594
# val epoch 5 : loss : 0.5800, acc: 0.7267, bma: 0.7107
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.5461, acc: 0.7515, bma: 0.7658
# val epoch 6 : loss : 0.5449, acc: 0.7333, bma: 0.7155
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.5232, acc: 0.7575, bma: 0.7745
# val epoch 7 : loss : 0.5513, acc: 0.7267, bma: 0.7222
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.4507, acc: 0.7880, bma: 0.8110
# val epoch 8 : loss : 0.4837, acc: 0.7533, bma: 0.7457
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.4414, acc: 0.7985, bma: 0.8136
# val epoch 9 : loss : 0.4519, acc: 0.7800, bma: 0.7728
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.4297, acc: 0.8050, bma: 0.8228
# val epoch 10 : loss : 0.5029, acc: 0.7733, bma: 0.7407
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.3708, acc: 0.8290, bma: 0.8441
# val epoch 11 : loss : 0.5648, acc: 0.7533, bma: 0.6978
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.3588, acc: 0.8405, bma: 0.8581
# val epoch 12 : loss : 0.4058, acc: 0.7867, bma: 0.7875
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.3055, acc: 0.8575, bma: 0.8816
# val epoch 13 : loss : 0.6021, acc: 0.7467, bma: 0.6994
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.3199, acc: 0.8485, bma: 0.8613
# val epoch 14 : loss : 0.5471, acc: 0.7600, bma: 0.7248
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.2691, acc: 0.8730, bma: 0.8930
# val epoch 15 : loss : 0.4572, acc: 0.7867, bma: 0.7976
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.2620, acc: 0.8730, bma: 0.8958
# val epoch 16 : loss : 0.4599, acc: 0.7600, bma: 0.7499
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.2411, acc: 0.8890, bma: 0.9047
# val epoch 17 : loss : 0.4776, acc: 0.7867, bma: 0.7934
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.2476, acc: 0.8900, bma: 0.9037
# val epoch 18 : loss : 0.5528, acc: 0.7600, bma: 0.7221
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.2135, acc: 0.9050, bma: 0.9183
# val epoch 19 : loss : 0.5509, acc: 0.7467, bma: 0.7231
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.2007, acc: 0.9060, bma: 0.9194
# val epoch 20 : loss : 0.5556, acc: 0.8133, bma: 0.8037
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.2042, acc: 0.9015, bma: 0.9157
# val epoch 21 : loss : 0.5473, acc: 0.8000, bma: 0.7919
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.1945, acc: 0.9210, bma: 0.9379
# val epoch 22 : loss : 0.4724, acc: 0.8267, bma: 0.8190
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.1966, acc: 0.9230, bma: 0.9303
# val epoch 23 : loss : 0.4859, acc: 0.7867, bma: 0.7729
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.1375, acc: 0.9505, bma: 0.9576
# val epoch 24 : loss : 0.6082, acc: 0.8200, bma: 0.7742
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.1188, acc: 0.9525, bma: 0.9646
# val epoch 25 : loss : 0.6825, acc: 0.8067, bma: 0.7584
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.1044, acc: 0.9620, bma: 0.9682
# val epoch 26 : loss : 0.5704, acc: 0.7867, bma: 0.7387
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.0878, acc: 0.9635, bma: 0.9730
# val epoch 27 : loss : 0.8002, acc: 0.7933, bma: 0.7325
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.0939, acc: 0.9640, bma: 0.9717
# val epoch 28 : loss : 0.6661, acc: 0.7733, bma: 0.7201
# EARLY STOP AFTER 28 EPOCHS
# Training complete in 137m 50s
# Best val loss: 0.405760
# Best val BMA: 0.8190476190476191

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(vit, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.6922 Acc: 0.7333, BMA: 0.7289
# Testing complete in 3m 25s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.6922, acc: 0.7333, bma: 0.7289

# %% [markdown]
# Show some results

# %%
visualize_model(vit, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 0
# Actual: 2, predicted: 1

# %% [markdown]
# ## 3. ConvNext

# %% [markdown]
# #### With Focal Loss

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/Tensorboard_class/convnext/convnext_fl_sgd.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/Tensorboard_class/convnext'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-6

# %%
convnext  = make_convnext(True)

criterion = FocalLoss(alpha = class_weights, gamma = 2.0, size_average= True)

optimizer = optim.SGD(convnext.parameters(), lr = LR, weight_decay=WD, momentum = 0.9)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.1, mode="min")

# %%
logging.info('Model: ConvNext, Base LR: 1e-4, LR patience = 5, loss: Focal, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-6, momentum = 0.9')
# Out:
# Model: ConvNext, Base LR: 1e-4, LR patience = 5, loss: Focal, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-6, momentum = 0.9

# %%
convnext = train_model(convnext, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.4504, acc: 0.4585, bma: 0.4780
# val epoch 1 : loss : 0.5211, acc: 0.4200, bma: 0.4558
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.3886, acc: 0.5340, bma: 0.5683
# val epoch 2 : loss : 0.4655, acc: 0.5267, bma: 0.5452
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.3556, acc: 0.5505, bma: 0.5950
# val epoch 3 : loss : 0.4852, acc: 0.6000, bma: 0.6112
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.3315, acc: 0.5720, bma: 0.6297
# val epoch 4 : loss : 0.4734, acc: 0.6267, bma: 0.6015
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.3227, acc: 0.6090, bma: 0.6447
# val epoch 5 : loss : 0.4255, acc: 0.6267, bma: 0.6261
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.3095, acc: 0.5970, bma: 0.6434
# val epoch 6 : loss : 0.4275, acc: 0.6200, bma: 0.6082
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.2894, acc: 0.6285, bma: 0.6758
# val epoch 7 : loss : 0.4338, acc: 0.6533, bma: 0.6737
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.2774, acc: 0.6405, bma: 0.6886
# val epoch 8 : loss : 0.5025, acc: 0.7200, bma: 0.6987
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.2697, acc: 0.6360, bma: 0.6888
# val epoch 9 : loss : 0.3976, acc: 0.6667, bma: 0.6623
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.2674, acc: 0.6370, bma: 0.6854
# val epoch 10 : loss : 0.3889, acc: 0.6800, bma: 0.6740
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.2536, acc: 0.6435, bma: 0.6848
# val epoch 11 : loss : 0.4000, acc: 0.7200, bma: 0.7238
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.2518, acc: 0.6715, bma: 0.7215
# val epoch 12 : loss : 0.3932, acc: 0.6600, bma: 0.6375
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.2501, acc: 0.6495, bma: 0.7004
# val epoch 13 : loss : 0.3573, acc: 0.6533, bma: 0.6647
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.2476, acc: 0.6550, bma: 0.7018
# val epoch 14 : loss : 0.4023, acc: 0.6800, bma: 0.6977
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.2404, acc: 0.6740, bma: 0.7222
# val epoch 15 : loss : 0.3697, acc: 0.7067, bma: 0.6984
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.2275, acc: 0.6680, bma: 0.7232
# val epoch 16 : loss : 0.3576, acc: 0.7133, bma: 0.6927
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.2237, acc: 0.6875, bma: 0.7334
# val epoch 17 : loss : 0.3890, acc: 0.7133, bma: 0.7154
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.2265, acc: 0.6785, bma: 0.7229
# val epoch 18 : loss : 0.3557, acc: 0.7267, bma: 0.7317
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.2173, acc: 0.6850, bma: 0.7424
# val epoch 19 : loss : 0.3891, acc: 0.7133, bma: 0.6758
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.2051, acc: 0.7075, bma: 0.7622
# val epoch 20 : loss : 0.3520, acc: 0.7267, bma: 0.7112
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.2163, acc: 0.7020, bma: 0.7372
# val epoch 21 : loss : 0.3328, acc: 0.7400, bma: 0.7676
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.2189, acc: 0.6985, bma: 0.7471
# val epoch 22 : loss : 0.3025, acc: 0.7000, bma: 0.7110
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.2100, acc: 0.6985, bma: 0.7424
# val epoch 23 : loss : 0.3327, acc: 0.7467, bma: 0.7514
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.2013, acc: 0.7085, bma: 0.7505
# val epoch 24 : loss : 0.3036, acc: 0.7200, bma: 0.7243
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.2011, acc: 0.7070, bma: 0.7510
# val epoch 25 : loss : 0.3590, acc: 0.7333, bma: 0.7419
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.2065, acc: 0.7065, bma: 0.7430
# val epoch 26 : loss : 0.3421, acc: 0.7467, bma: 0.7104
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.1817, acc: 0.7360, bma: 0.7735
# val epoch 27 : loss : 0.3099, acc: 0.7333, bma: 0.7597
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.1807, acc: 0.7335, bma: 0.7787
# val epoch 28 : loss : 0.3258, acc: 0.7267, bma: 0.7481
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.1676, acc: 0.7440, bma: 0.7905
# val epoch 29 : loss : 0.3019, acc: 0.7533, bma: 0.7589
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.1717, acc: 0.7420, bma: 0.7812
# val epoch 30 : loss : 0.2940, acc: 0.7400, bma: 0.7540
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.1644, acc: 0.7595, bma: 0.7986
# val epoch 31 : loss : 0.2954, acc: 0.7333, bma: 0.7460
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.1578, acc: 0.7620, bma: 0.8092
# val epoch 32 : loss : 0.3015, acc: 0.7533, bma: 0.7552
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.1620, acc: 0.7545, bma: 0.7932
# val epoch 33 : loss : 0.2960, acc: 0.7533, bma: 0.7589
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.1585, acc: 0.7580, bma: 0.7975
# val epoch 34 : loss : 0.2904, acc: 0.7267, bma: 0.7317
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.1614, acc: 0.7345, bma: 0.7848
# val epoch 35 : loss : 0.2967, acc: 0.7400, bma: 0.7471
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.1624, acc: 0.7440, bma: 0.7866
# val epoch 36 : loss : 0.2984, acc: 0.7667, bma: 0.7611
#
# Epoch 37/100
# ----------
# train epoch 37 : loss : 0.1602, acc: 0.7635, bma: 0.8077
# val epoch 37 : loss : 0.2922, acc: 0.7533, bma: 0.7625
#
# Epoch 38/100
# ----------
# train epoch 38 : loss : 0.1554, acc: 0.7575, bma: 0.8057
# val epoch 38 : loss : 0.2956, acc: 0.7467, bma: 0.7514
#
# Epoch 39/100
# ----------
# train epoch 39 : loss : 0.1593, acc: 0.7660, bma: 0.7979
# val epoch 39 : loss : 0.2928, acc: 0.7467, bma: 0.7514
#
# Epoch 40/100
# ----------
# train epoch 40 : loss : 0.1564, acc: 0.7565, bma: 0.8004
# val epoch 40 : loss : 0.2942, acc: 0.7533, bma: 0.7625
#
# Epoch 41/100
# ----------
# train epoch 41 : loss : 0.1558, acc: 0.7560, bma: 0.7987
# val epoch 41 : loss : 0.2950, acc: 0.7533, bma: 0.7625
#
# Epoch 42/100
# ----------
# train epoch 42 : loss : 0.1590, acc: 0.7545, bma: 0.7988
# val epoch 42 : loss : 0.2944, acc: 0.7600, bma: 0.7736
#
# Epoch 43/100
# ----------
# train epoch 43 : loss : 0.1542, acc: 0.7570, bma: 0.8013
# val epoch 43 : loss : 0.2945, acc: 0.7600, bma: 0.7736
#
# Epoch 44/100
# ----------
# train epoch 44 : loss : 0.1605, acc: 0.7460, bma: 0.7889
# val epoch 44 : loss : 0.2941, acc: 0.7600, bma: 0.7736
#
# Epoch 45/100
# ----------
# train epoch 45 : loss : 0.1487, acc: 0.7600, bma: 0.8112
# val epoch 45 : loss : 0.2942, acc: 0.7600, bma: 0.7736
# EARLY STOP AFTER 45 EPOCHS
# Training complete in 223m 59s
# Best val loss: 0.290396
# Best val BMA: 0.7736263736263735

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(convnext, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.3341 Acc: 0.6167, BMA: 0.6600
# Testing complete in 6m 15s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.3341, acc: 0.6167, bma: 0.6600

# %% [markdown]
# Show some results

# %%
visualize_model(convnext, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 2
# Actual: 0, predicted: 2
# Actual: 0, predicted: 2
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/Tensorboard_class/convnext/convnext_fl_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/Tensorboard_class/convnext'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 0

# %%
convnext  = make_convnext(True)

criterion = FocalLoss(alpha = class_weights, gamma = 2.0, size_average= True)

optimizer = optim.Adam(convnext.parameters(), lr = LR, weight_decay=WD)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.1, mode="min")

# %%
logging.info('Model: ConvNext, Base LR: 1e-4, LR patience = 5, loss: Focal, optim: ADAM, lr_sched: ReduceOnPlat, WD = 0')
# Out:
# Model: ConvNext, Base LR: 1e-4, LR patience = 5, loss: Focal, optim: ADAM, lr_sched: ReduceOnPlat, WD = 0

# %%
convnext = train_model(convnext, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.4003, acc: 0.4985, bma: 0.5397
# val epoch 1 : loss : 0.3881, acc: 0.6933, bma: 0.6794
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.2854, acc: 0.6165, bma: 0.6737
# val epoch 2 : loss : 0.3332, acc: 0.6867, bma: 0.6919
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.2487, acc: 0.6760, bma: 0.7121
# val epoch 3 : loss : 0.2619, acc: 0.6333, bma: 0.6761
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.2010, acc: 0.6950, bma: 0.7510
# val epoch 4 : loss : 0.3824, acc: 0.7333, bma: 0.6730
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.1898, acc: 0.7175, bma: 0.7647
# val epoch 5 : loss : 0.2215, acc: 0.7800, bma: 0.7938
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.1495, acc: 0.7740, bma: 0.8070
# val epoch 6 : loss : 0.1661, acc: 0.7667, bma: 0.8016
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.1421, acc: 0.7835, bma: 0.8233
# val epoch 7 : loss : 0.2359, acc: 0.7533, bma: 0.7689
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.1402, acc: 0.7900, bma: 0.8312
# val epoch 8 : loss : 0.3560, acc: 0.6800, bma: 0.7055
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.1406, acc: 0.8005, bma: 0.8279
# val epoch 9 : loss : 0.2494, acc: 0.7933, bma: 0.7540
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.0846, acc: 0.8490, bma: 0.8833
# val epoch 10 : loss : 0.3368, acc: 0.8267, bma: 0.7949
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.0945, acc: 0.8505, bma: 0.8789
# val epoch 11 : loss : 0.2429, acc: 0.7133, bma: 0.7137
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.0921, acc: 0.8500, bma: 0.8801
# val epoch 12 : loss : 0.2867, acc: 0.8000, bma: 0.8093
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.0604, acc: 0.9115, bma: 0.9292
# val epoch 13 : loss : 0.2217, acc: 0.8333, bma: 0.8375
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.0473, acc: 0.9240, bma: 0.9383
# val epoch 14 : loss : 0.2387, acc: 0.8267, bma: 0.8164
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.0347, acc: 0.9420, bma: 0.9554
# val epoch 15 : loss : 0.2613, acc: 0.8333, bma: 0.8138
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.0344, acc: 0.9475, bma: 0.9626
# val epoch 16 : loss : 0.2556, acc: 0.8267, bma: 0.8095
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.0286, acc: 0.9510, bma: 0.9650
# val epoch 17 : loss : 0.2676, acc: 0.8333, bma: 0.8206
# EARLY STOP AFTER 17 EPOCHS
# Training complete in 83m 0s
# Best val loss: 0.166110
# Best val BMA: 0.8374847374847375

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(convnext, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.3410 Acc: 0.7350, BMA: 0.7311
# Testing complete in 3m 26s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.3410, acc: 0.7350, bma: 0.7311

# %% [markdown]
# Show some results

# %%
visualize_model(convnext, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 2
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %% [markdown]
# #### With Weighted Cross Entropy

# %% [markdown]
# ##### With SGD

# %%
logging.basicConfig(filename="/content/drive/MyDrive/Tensorboard_class/convnext/convnext_wce_sgd.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/Tensorboard_class/convnext'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
convnext = make_convnext(True)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.SGD(convnext.parameters(), lr = LR, weight_decay=WD, momentum = 0.9)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.1, mode="min")

# %%
logging.info('Model: ConvNext, LR init: 1e-4, LR patience = 5, loss: WCE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9')
# Out:
# Model: ConvNext, LR init: 1e-4, LR patience = 5, loss: WCE, optim: SGD, lr_sched: ReduceOnPlat, WD = 1e-8, momentum = 0.9

# %%
vit = train_model(convnext, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 1.0172, acc: 0.5220, bma: 0.4672
# val epoch 1 : loss : 0.8820, acc: 0.5733, bma: 0.5646
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.9104, acc: 0.5680, bma: 0.5678
# val epoch 2 : loss : 0.8400, acc: 0.6667, bma: 0.6352
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.8111, acc: 0.6260, bma: 0.6353
# val epoch 3 : loss : 0.7983, acc: 0.6600, bma: 0.6697
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.7601, acc: 0.6555, bma: 0.6611
# val epoch 4 : loss : 0.6760, acc: 0.6867, bma: 0.6846
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.7368, acc: 0.6515, bma: 0.6692
# val epoch 5 : loss : 0.6426, acc: 0.7133, bma: 0.7017
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.7249, acc: 0.6710, bma: 0.6835
# val epoch 6 : loss : 0.6053, acc: 0.6867, bma: 0.6998
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.6643, acc: 0.6830, bma: 0.7135
# val epoch 7 : loss : 0.7316, acc: 0.6400, bma: 0.6510
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.6801, acc: 0.6830, bma: 0.7097
# val epoch 8 : loss : 0.6275, acc: 0.7400, bma: 0.7435
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.6338, acc: 0.7035, bma: 0.7280
# val epoch 9 : loss : 0.6624, acc: 0.7133, bma: 0.7107
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.6259, acc: 0.6990, bma: 0.7267
# val epoch 10 : loss : 0.5980, acc: 0.7333, bma: 0.7260
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.5952, acc: 0.7145, bma: 0.7394
# val epoch 11 : loss : 0.5918, acc: 0.7467, bma: 0.7299
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.5879, acc: 0.7185, bma: 0.7383
# val epoch 12 : loss : 0.5696, acc: 0.7000, bma: 0.7252
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.5646, acc: 0.7275, bma: 0.7587
# val epoch 13 : loss : 0.6244, acc: 0.7267, bma: 0.7049
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.5760, acc: 0.7335, bma: 0.7610
# val epoch 14 : loss : 0.6638, acc: 0.7200, bma: 0.6564
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.5322, acc: 0.7490, bma: 0.7706
# val epoch 15 : loss : 0.5300, acc: 0.7733, bma: 0.7758
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.5263, acc: 0.7640, bma: 0.7869
# val epoch 16 : loss : 0.5599, acc: 0.7133, bma: 0.7342
#
# Epoch 17/100
# ----------
# train epoch 17 : loss : 0.5557, acc: 0.7430, bma: 0.7659
# val epoch 17 : loss : 0.5274, acc: 0.7667, bma: 0.7816
#
# Epoch 18/100
# ----------
# train epoch 18 : loss : 0.5231, acc: 0.7550, bma: 0.7750
# val epoch 18 : loss : 0.4961, acc: 0.7867, bma: 0.8044
#
# Epoch 19/100
# ----------
# train epoch 19 : loss : 0.5169, acc: 0.7695, bma: 0.7905
# val epoch 19 : loss : 0.6553, acc: 0.7667, bma: 0.7022
#
# Epoch 20/100
# ----------
# train epoch 20 : loss : 0.4948, acc: 0.7710, bma: 0.8032
# val epoch 20 : loss : 0.5018, acc: 0.7667, bma: 0.7752
#
# Epoch 21/100
# ----------
# train epoch 21 : loss : 0.4640, acc: 0.7860, bma: 0.8112
# val epoch 21 : loss : 0.5462, acc: 0.7267, bma: 0.7144
#
# Epoch 22/100
# ----------
# train epoch 22 : loss : 0.4714, acc: 0.7745, bma: 0.8045
# val epoch 22 : loss : 0.5504, acc: 0.7667, bma: 0.7442
#
# Epoch 23/100
# ----------
# train epoch 23 : loss : 0.4726, acc: 0.7865, bma: 0.8079
# val epoch 23 : loss : 0.5129, acc: 0.7667, bma: 0.7979
#
# Epoch 24/100
# ----------
# train epoch 24 : loss : 0.4896, acc: 0.7645, bma: 0.7880
# val epoch 24 : loss : 0.5075, acc: 0.7933, bma: 0.7850
#
# Epoch 25/100
# ----------
# train epoch 25 : loss : 0.4024, acc: 0.8135, bma: 0.8402
# val epoch 25 : loss : 0.4788, acc: 0.8067, bma: 0.8004
#
# Epoch 26/100
# ----------
# train epoch 26 : loss : 0.3875, acc: 0.8280, bma: 0.8508
# val epoch 26 : loss : 0.4869, acc: 0.8133, bma: 0.8046
#
# Epoch 27/100
# ----------
# train epoch 27 : loss : 0.3823, acc: 0.8275, bma: 0.8494
# val epoch 27 : loss : 0.4809, acc: 0.8067, bma: 0.8109
#
# Epoch 28/100
# ----------
# train epoch 28 : loss : 0.3797, acc: 0.8260, bma: 0.8579
# val epoch 28 : loss : 0.4865, acc: 0.8200, bma: 0.8089
#
# Epoch 29/100
# ----------
# train epoch 29 : loss : 0.3668, acc: 0.8320, bma: 0.8573
# val epoch 29 : loss : 0.4860, acc: 0.8200, bma: 0.8126
#
# Epoch 30/100
# ----------
# train epoch 30 : loss : 0.3482, acc: 0.8300, bma: 0.8614
# val epoch 30 : loss : 0.4993, acc: 0.8267, bma: 0.8132
#
# Epoch 31/100
# ----------
# train epoch 31 : loss : 0.3760, acc: 0.8235, bma: 0.8530
# val epoch 31 : loss : 0.4849, acc: 0.8200, bma: 0.8121
#
# Epoch 32/100
# ----------
# train epoch 32 : loss : 0.3457, acc: 0.8465, bma: 0.8752
# val epoch 32 : loss : 0.4828, acc: 0.8200, bma: 0.8121
#
# Epoch 33/100
# ----------
# train epoch 33 : loss : 0.3543, acc: 0.8330, bma: 0.8591
# val epoch 33 : loss : 0.4822, acc: 0.8200, bma: 0.8121
#
# Epoch 34/100
# ----------
# train epoch 34 : loss : 0.3434, acc: 0.8510, bma: 0.8733
# val epoch 34 : loss : 0.4833, acc: 0.8333, bma: 0.8280
#
# Epoch 35/100
# ----------
# train epoch 35 : loss : 0.3508, acc: 0.8325, bma: 0.8647
# val epoch 35 : loss : 0.4820, acc: 0.8267, bma: 0.8168
#
# Epoch 36/100
# ----------
# train epoch 36 : loss : 0.3554, acc: 0.8315, bma: 0.8601
# val epoch 36 : loss : 0.4817, acc: 0.8267, bma: 0.8168
# EARLY STOP AFTER 36 EPOCHS
# Training complete in 175m 51s
# Best val loss: 0.478790
# Best val BMA: 0.827960927960928

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(convnext, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.6937 Acc: 0.7000, BMA: 0.7182
# Testing complete in 3m 30s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))

# %% [markdown]
# Show some results

# %%
visualize_model(convnext, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1

# %% [markdown]
# ##### With ADAM

# %%
logging.basicConfig(filename="/content/drive/MyDrive/Tensorboard_class/convnext/convnext_wce_adam.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
writer_path = '/content/drive/MyDrive/Tensorboard_class/convnext'

# %%
# Parameters 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # Device used
LR = 1e-4
LR_PATIENCE = 5
ES_PATIENCE = 10

EPOCHS = 100
WD = 1e-8

# %%
convnext =  make_convnext(True)

criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(convnext.parameters(), lr = LR, weight_decay=WD)

lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience= LR_PATIENCE, factor = 0.5, mode="min")

# %%
logging.info('Model: ConvNext, LR: 1e-4, LR patience = 5, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8')
# Out:
# Model: ConvNext, LR: 1e-4, LR patience = 5, loss: WCE, optim: ADAM, lr_sched: ReduceOnPlat, WD = 1e-8

# %%
convnext = train_model(convnext, dataloaders, criterion, optimizer, lr_scheduler, early_stop_patience=ES_PATIENCE, num_epochs=EPOCHS, writer_path = writer_path)
# Out:
# Epoch 1/100
# ----------
# train epoch 1 : loss : 0.8891, acc: 0.5585, bma: 0.5710
# val epoch 1 : loss : 0.5759, acc: 0.7133, bma: 0.6927
#
# Epoch 2/100
# ----------
# train epoch 2 : loss : 0.6700, acc: 0.6795, bma: 0.7022
# val epoch 2 : loss : 0.5313, acc: 0.7867, bma: 0.7397
#
# Epoch 3/100
# ----------
# train epoch 3 : loss : 0.5630, acc: 0.7460, bma: 0.7712
# val epoch 3 : loss : 0.4581, acc: 0.8267, bma: 0.7890
#
# Epoch 4/100
# ----------
# train epoch 4 : loss : 0.5171, acc: 0.7730, bma: 0.7895
# val epoch 4 : loss : 0.4125, acc: 0.8000, bma: 0.8330
#
# Epoch 5/100
# ----------
# train epoch 5 : loss : 0.4146, acc: 0.8025, bma: 0.8170
# val epoch 5 : loss : 0.3928, acc: 0.7933, bma: 0.8150
#
# Epoch 6/100
# ----------
# train epoch 6 : loss : 0.4029, acc: 0.8145, bma: 0.8282
# val epoch 6 : loss : 0.5040, acc: 0.8133, bma: 0.7968
#
# Epoch 7/100
# ----------
# train epoch 7 : loss : 0.3235, acc: 0.8520, bma: 0.8718
# val epoch 7 : loss : 0.4815, acc: 0.8200, bma: 0.7742
#
# Epoch 8/100
# ----------
# train epoch 8 : loss : 0.3193, acc: 0.8510, bma: 0.8662
# val epoch 8 : loss : 0.5064, acc: 0.7867, bma: 0.7538
#
# Epoch 9/100
# ----------
# train epoch 9 : loss : 0.2773, acc: 0.8725, bma: 0.8891
# val epoch 9 : loss : 0.8149, acc: 0.7467, bma: 0.7172
#
# Epoch 10/100
# ----------
# train epoch 10 : loss : 0.2359, acc: 0.8890, bma: 0.9043
# val epoch 10 : loss : 0.7024, acc: 0.8067, bma: 0.7994
#
# Epoch 11/100
# ----------
# train epoch 11 : loss : 0.2753, acc: 0.8845, bma: 0.8991
# val epoch 11 : loss : 0.5182, acc: 0.8333, bma: 0.8028
#
# Epoch 12/100
# ----------
# train epoch 12 : loss : 0.1278, acc: 0.9485, bma: 0.9567
# val epoch 12 : loss : 0.5447, acc: 0.7800, bma: 0.7628
#
# Epoch 13/100
# ----------
# train epoch 13 : loss : 0.0940, acc: 0.9600, bma: 0.9676
# val epoch 13 : loss : 0.5780, acc: 0.8533, bma: 0.8166
#
# Epoch 14/100
# ----------
# train epoch 14 : loss : 0.0885, acc: 0.9575, bma: 0.9677
# val epoch 14 : loss : 0.7361, acc: 0.8467, bma: 0.8228
#
# Epoch 15/100
# ----------
# train epoch 15 : loss : 0.0705, acc: 0.9725, bma: 0.9802
# val epoch 15 : loss : 0.5991, acc: 0.8067, bma: 0.7930
#
# Epoch 16/100
# ----------
# train epoch 16 : loss : 0.0713, acc: 0.9670, bma: 0.9740
# val epoch 16 : loss : 0.6840, acc: 0.8333, bma: 0.8070
# EARLY STOP AFTER 16 EPOCHS
# Training complete in 79m 14s
# Best val loss: 0.392754
# Best val BMA: 0.832967032967033

# %% [markdown]
# Test

# %%
test_loss, test_acc, test_bma = test_model(convnext, test_loader, DEVICE, criterion)
# Out:
# Test Loss: 0.7113 Acc: 0.6367, BMA: 0.7197
# Testing complete in 3m 26s

# %%
logging.info('Test loss: %.4f, acc: %.4f, bma: %.4f' % (test_loss, test_acc, test_bma))
# Out:
# Test loss: 0.7113, acc: 0.6367, bma: 0.7197

# %% [markdown]
# Show some results

# %%
visualize_model(convnext, test_loader, DEVICE, num_images=10)
# Out:
# Actual: 2, predicted: 2
# Actual: 0, predicted: 1
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 2
# Actual: 0, predicted: 0
# Actual: 0, predicted: 2
# Actual: 0, predicted: 0
# Actual: 2, predicted: 2
# Actual: 2, predicted: 1
